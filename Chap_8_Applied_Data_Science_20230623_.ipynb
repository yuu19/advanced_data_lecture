# %% [markdown]
# <a href="https://colab.research.google.com/github/yuu19/advanced_data_lecture/blob/main/Chap_8_Applied_Data_Science_20230623_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #8. <font color='crimson'>Text Analysis - Part II </font>
#
# **Today's highlight**：
#
# - WordCloud
#
# - Sentiment Analysis

# %% [markdown]
# ## 8.1 <font color="Crimson">**Word Cloud**</font>
#
# Word cloud is a popular techniques that intuitively show the important words contains in a text by controlling the size of word using Frequency.

# %% [markdown]
# https://raw.githubusercontent.com/dgod1028/Research/main/data/sendai_eco.txt

# %% [markdown]
# Let's download the text file first.

# %%
# !wget https://raw.githubusercontent.com/dgod1028/Research/main/data/sendai_eco.txt
# Out:
# --2023-06-30 01:31:18--  https://raw.githubusercontent.com/dgod1028/Research/main/data/sendai_eco.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1513 (1.5K) [text/plain]
# Saving to: ‘sendai_eco.txt’
#
# sendai_eco.txt      100%[===================>]   1.48K  --.-KB/s    in 0s
#
# 2023-06-30 01:31:18 (24.0 MB/s) - ‘sendai_eco.txt’ saved [1513/1513]

# %%
with open('sendai_eco.txt', 'r') as f:
  text = f.read()
text
# Out:
# "Economy\nSendai is the center of the Tōhoku region's economy, and is the base of the region's logistics and transportation. The GDP in Greater Sendai, Sendai Metropolitan Employment Area (1.6 million people), is US$61.7 billion in 2010.[16][17] Sendai city by itself has a nominal GDP of approximately US$50 billion as of 2015.[18] The city's economy heavily relies upon retail and services – the two industries provide approximately two thirds of the employment and close to half of the establishments.\n\nSendai is frequently called a branch-office economy[by whom?], because very few major companies are headquartered in the city. Various authorities are cooperating to alleviate this problem, primarily by encouraging high-tech ventures from Tohoku University, which is well known for its science and engineering departments. There are also incentives for startups available from the prefectural government.[19]\n\nTohoku Electric Power, a major regional supplier of electric power, has its headquarters in Sendai and also operates the Shin-Sendai Thermal Power Station located within the city.\n\nSendai's economic growth rate has stabilized since the 2011 Japan earthquake. The growth rate was only 0.4% in 2011 after the quake created economic turmoil in coastal areas. The year after, in 2012 the rate spiked to 10.4% after reconstruction efforts. It has since fallen to a closer trend to what is expected of 3.7% in 2013.[20]\n\nTourism in 2016 attracted an estimated 2.229 million visitors to Sendai."

# %%
from wordcloud import WordCloud # ワードクラウドのライブラリ
import matplotlib.pyplot as plt # 可視化ライブラリ


wordcloud = WordCloud(background_color="white",
    width=800,height=600).generate(text)

wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=800x600 at 0x7F107FDC28C0>

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

text2 = text

tmp = text2.split(' ')
new_text = [word for word in tmp if word not in stop_words ]
new_text2 = ' '.join(new_text)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
wordcloud = WordCloud(background_color="white",
    width=800,height=600).generate(new_text2)

wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=800x600 at 0x7F107C2AB820>

# %% [markdown]
# Also, if you want only the nouns, then you can use textblob.

# %%
from textblob import TextBlob
nltk.download('brown') # requirements
nltk.download('punkt') # requirements
blob = TextBlob(new_text2)
blob.noun_phrases
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# WordList(['economy sendai', 'tōhoku', "region 's economy", "base region 's logistics transportation", 'gdp', 'sendai', 'sendai', 'employment', 'us $', '] [', 'sendai', 'gdp', 'us $', "city 's economy", 'retail services –', 'thirds employment', 'sendai', 'branch-office economy [', 'major companies', 'various authorities', 'alleviate problem', 'encouraging high-tech ventures', 'tohoku', 'science engineering departments', 'incentives startups', 'available prefectural government', 'tohoku', 'power', 'major regional supplier', 'electric power', 'sendai', 'shin-sendai thermal power', 'sendai', 'economic growth rate', 'japan', 'growth rate', 'coastal areas', '% reconstruction efforts', 'tourism', 'sendai'])

# %% [markdown]
# #### <font color='crimson'>**[Practice 1]Remove punctuations and visualize using wordcloud** (10 mins)</font>
#
# 1. Choose only noun words for the text.
#
# 1. Remove the punctuations and non-character words such as ' $ [ ], then make wordcloud again.

# %%
# Start here

# 1
new_text = ' '.join(blob.noun_phrases)
new_text

# 2
import re
text3 = re.subn('\n', ' ', new_text)[0]
text4 = re.subn('[^\w\s]', '', text3)[0]
text5 = re.subn('\s+',' ', text4)[0]

text5
# Out:
# 'economy sendai tōhoku region s economy base region s logistics transportation gdp sendai sendai employment us sendai gdp us city s economy retail services thirds employment sendai branchoffice economy major companies various authorities alleviate problem encouraging hightech ventures tohoku science engineering departments incentives startups available prefectural government tohoku power major regional supplier electric power sendai shinsendai thermal power sendai economic growth rate japan growth rate coastal areas reconstruction efforts tourism sendai'

# %%
wordcloud = WordCloud(background_color="white",
    width=800,height=600).generate(text5)

wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=800x600 at 0x7F105074E890>

# %% [markdown]
# ## 8.2 <font color="Crimson">**Sentiment**</font>
#
# Sentiment analysis is a method for analyzing latent emotions from text. Emotion analysis methods are diversifying, and various methods have been proposed in addition to the two options of 'positive emotion' and 'negative emotion'.
#
# <div align="center">
# <img src="https://drive.google.com/uc?export=view&id=18zHK9ZuFIoaTn_b0wphrl4DWhkb_vZFB" width="60%">
# </div>

# %% [markdown]
# In the past, we need to train the sentiment analysis models with manually tagged data by ourselves. But nowadays there are various open-sourced sentiment analysis models. Thus, we don't need to train the models anymore in most cases.
#
# In this lecture we will use a simple sentiment model trained by other researchers.

# %%
# install the module
# !pip install -q transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 31.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 21.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 52.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 30.7 MB/s eta 0:00:00

# %%
# Sentiment analysis
from transformers import pipeline
sentiment_pipeline = pipeline("sentiment-analysis", 'distilbert-base-uncased-finetuned-sst-2-english')
data = ["This is great!", "I hate programming!"]
sentiment_pipeline(data)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.
# [{'label': 'POSITIVE', 'score': 0.9998694658279419},
#  {'label': 'NEGATIVE', 'score': 0.9996341466903687}]

# %% [markdown]
# But this model not work well sometimes.

# %%
data = "This is a desk."
sentiment_pipeline(data)
# Out:
# [{'label': 'POSITIVE', 'score': 0.8734818696975708}]

# %% [markdown]
# ### <font color='crimson'>**[Practice 2]Sentiment Analysis** (remained)</font>
#
# Here is the twitter data posted by Trump from 2009 ~ 20016.
#
# 1. Calculate the proportion of **positive tweets** for the **first 200 tweets**. You only need to use column 'Tweet' for this problem.
#
# 1. Create 2 WordCloud based on the positive and negative comments,respectively.
#
# ★ Challenge ★
#
# 1. Download the sentiments file (I classified all the tweets), and using the tweets data and this file, calculate the proportion of **positive tweets** for each year, respectively.
#
# 1. Visualize the proportion of positive tweets for each year.
#
# 1. How about calculate the proportion of the positive tweets for each month?

# %%
import pandas as pd
import numpy as np

df_tweets = pd.read_csv('https://raw.githubusercontent.com/dgod1028/Research/main/data/2016_12_05-TrumpTwitterAll.csv',encoding='cp932')
df_tweets
# Out:
#              Date         Time  \
# 0      12/05/2016  12:00:27 PM
# 1      12/05/2016   9:53:11 AM
# 2      12/04/2016   6:30:22 PM
# 3      12/04/2016   6:23:55 PM
# 4      12/04/2016   5:47:21 PM
# ...           ...          ...
# 30073  05/12/2009  10:07:28 AM
# 30074  05/08/2009   4:40:15 PM
# 30075  05/08/2009   9:38:08 AM
# 30076  05/04/2009   9:00:10 PM
# 30077  05/04/2009   2:54:25 PM
#
#                                                    Tweet               Client  \
# 0      If the press would cover me accurately & honor...   Twitter Web Client
# 1      I am thrilled to nominate Dr. @RealBenCarson a...   Twitter for iPhone
# 2      their country (the U.S. doesn't tax them) or t...  Twitter for Android
# 3      Did China ask us if it was OK to devalue their...  Twitter for Android
# 4      .@FoxNews will be re-running "Objectified: Don...  Twitter for Android
# ...                                                  ...                  ...
# 30073  "My persona will never be that of a wallflower...   Twitter Web Client
# 30074  New Blog Post: Celebrity Apprentice Finale and...   Twitter Web Client
# 30075  Donald Trump reads Top Ten Financial Tips on L...   Twitter Web Client
# 30076  Donald Trump will be appearing on The View tom...   Twitter Web Client
# 30077  Be sure to tune in and watch Donald Trump on L...   Twitter Web Client
#
#          Client Simplified
# 0       Twitter Web Client
# 1       Twitter for iPhone
# 2      Twitter for Android
# 3      Twitter for Android
# 4      Twitter for Android
# ...                    ...
# 30073   Twitter Web Client
# 30074   Twitter Web Client
# 30075   Twitter Web Client
# 30076   Twitter Web Client
# 30077   Twitter Web Client
#
# [30078 rows x 5 columns]

# %%
tweets = df_tweets['Tweet'][:200].tolist()
sents = sentiment_pipeline(tweets)

# %%
sents
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9997783303260803},
#  {'label': 'POSITIVE', 'score': 0.9984751343727112},
#  {'label': 'NEGATIVE', 'score': 0.9921970367431641},
#  {'label': 'NEGATIVE', 'score': 0.9995797276496887},
#  {'label': 'NEGATIVE', 'score': 0.9866687059402466},
#  {'label': 'NEGATIVE', 'score': 0.9997541308403015},
#  {'label': 'NEGATIVE', 'score': 0.9813768267631531},
#  {'label': 'POSITIVE', 'score': 0.9950882792472839},
#  {'label': 'NEGATIVE', 'score': 0.9952906370162964},
#  {'label': 'NEGATIVE', 'score': 0.9938435554504395},
#  {'label': 'NEGATIVE', 'score': 0.9994345307350159},
#  {'label': 'NEGATIVE', 'score': 0.9659892320632935},
#  {'label': 'NEGATIVE', 'score': 0.9989173412322998},
#  {'label': 'POSITIVE', 'score': 0.9996168613433838},
#  {'label': 'POSITIVE', 'score': 0.994712769985199},
#  {'label': 'POSITIVE', 'score': 0.9995182752609253},
#  {'label': 'NEGATIVE', 'score': 0.9994326233863831},
#  {'label': 'NEGATIVE', 'score': 0.9989601373672485},
#  {'label': 'POSITIVE', 'score': 0.9998445510864258},
#  {'label': 'POSITIVE', 'score': 0.9997283816337585},
#  {'label': 'POSITIVE', 'score': 0.6528462171554565},
#  {'label': 'POSITIVE', 'score': 0.9998102784156799},
#  {'label': 'POSITIVE', 'score': 0.9870457649230957},
#  {'label': 'POSITIVE', 'score': 0.9996875524520874},
#  {'label': 'NEGATIVE', 'score': 0.9490075707435608},
#  {'label': 'POSITIVE', 'score': 0.9931352138519287},
#  {'label': 'NEGATIVE', 'score': 0.7693285942077637},
#  {'label': 'POSITIVE', 'score': 0.9996815919876099},
#  {'label': 'POSITIVE', 'score': 0.9853838086128235},
#  {'label': 'NEGATIVE', 'score': 0.9452868700027466},
#  {'label': 'POSITIVE', 'score': 0.9997060894966125},
#  {'label': 'NEGATIVE', 'score': 0.6497565507888794},
#  {'label': 'NEGATIVE', 'score': 0.9934731125831604},
#  {'label': 'POSITIVE', 'score': 0.9998644590377808},
#  {'label': 'POSITIVE', 'score': 0.9974648952484131},
#  {'label': 'POSITIVE', 'score': 0.6550763845443726},
#  {'label': 'NEGATIVE', 'score': 0.9726647734642029},
#  {'label': 'POSITIVE', 'score': 0.9321540594100952},
#  {'label': 'POSITIVE', 'score': 0.9928432703018188},
#  {'label': 'NEGATIVE', 'score': 0.9987145662307739},
#  {'label': 'NEGATIVE', 'score': 0.9995736479759216},
#  {'label': 'POSITIVE', 'score': 0.9993427395820618},
#  {'label': 'NEGATIVE', 'score': 0.9994857311248779},
#  {'label': 'NEGATIVE', 'score': 0.9853712320327759},
#  {'label': 'NEGATIVE', 'score': 0.9996145963668823},
#  {'label': 'NEGATIVE', 'score': 0.9994233846664429},
#  {'label': 'NEGATIVE', 'score': 0.903042733669281},
#  {'label': 'POSITIVE', 'score': 0.9998190999031067},
#  {'label': 'NEGATIVE', 'score': 0.9992786049842834},
#  {'label': 'NEGATIVE', 'score': 0.999313235282898},
#  {'label': 'NEGATIVE', 'score': 0.7645209431648254},
#  {'label': 'NEGATIVE', 'score': 0.9993497729301453},
#  {'label': 'POSITIVE', 'score': 0.9995158910751343},
#  {'label': 'NEGATIVE', 'score': 0.9636471271514893},
#  {'label': 'NEGATIVE', 'score': 0.9911544322967529},
#  {'label': 'NEGATIVE', 'score': 0.9966493248939514},
#  {'label': 'NEGATIVE', 'score': 0.9971871972084045},
#  {'label': 'NEGATIVE', 'score': 0.9499408006668091},
#  {'label': 'NEGATIVE', 'score': 0.9984927177429199},
#  {'label': 'NEGATIVE', 'score': 0.9987892508506775},
#  {'label': 'NEGATIVE', 'score': 0.9951838850975037},
#  {'label': 'NEGATIVE', 'score': 0.9997169375419617},
#  {'label': 'NEGATIVE', 'score': 0.9974448680877686},
#  {'label': 'POSITIVE', 'score': 0.9960261583328247},
#  {'label': 'POSITIVE', 'score': 0.9998682737350464},
#  {'label': 'POSITIVE', 'score': 0.9997803568840027},
#  {'label': 'POSITIVE', 'score': 0.996793806552887},
#  {'label': 'POSITIVE', 'score': 0.9997791647911072},
#  {'label': 'POSITIVE', 'score': 0.9998168349266052},
#  {'label': 'POSITIVE', 'score': 0.9961389899253845},
#  {'label': 'POSITIVE', 'score': 0.997657060623169},
#  {'label': 'POSITIVE', 'score': 0.9996347427368164},
#  {'label': 'NEGATIVE', 'score': 0.9993690848350525},
#  {'label': 'NEGATIVE', 'score': 0.998572587966919},
#  {'label': 'NEGATIVE', 'score': 0.999765932559967},
#  {'label': 'POSITIVE', 'score': 0.9997844099998474},
#  {'label': 'NEGATIVE', 'score': 0.8915015459060669},
#  {'label': 'NEGATIVE', 'score': 0.9911250472068787},
#  {'label': 'POSITIVE', 'score': 0.9998466968536377},
#  {'label': 'POSITIVE', 'score': 0.9998338222503662},
#  {'label': 'NEGATIVE', 'score': 0.999725878238678},
#  {'label': 'POSITIVE', 'score': 0.9995439648628235},
#  {'label': 'NEGATIVE', 'score': 0.9992456436157227},
#  {'label': 'NEGATIVE', 'score': 0.9464575052261353},
#  {'label': 'NEGATIVE', 'score': 0.9995085000991821},
#  {'label': 'NEGATIVE', 'score': 0.9848068952560425},
#  {'label': 'NEGATIVE', 'score': 0.7635908722877502},
#  {'label': 'POSITIVE', 'score': 0.9998242259025574},
#  {'label': 'POSITIVE', 'score': 0.9405121803283691},
#  {'label': 'POSITIVE', 'score': 0.9989691972732544},
#  {'label': 'NEGATIVE', 'score': 0.9721605181694031},
#  {'label': 'POSITIVE', 'score': 0.9997723698616028},
#  {'label': 'NEGATIVE', 'score': 0.72445148229599},
#  {'label': 'NEGATIVE', 'score': 0.5133752822875977},
#  {'label': 'NEGATIVE', 'score': 0.9862646460533142},
#  {'label': 'NEGATIVE', 'score': 0.9988806843757629},
#  {'label': 'POSITIVE', 'score': 0.6175934672355652},
#  {'label': 'POSITIVE', 'score': 0.9996817111968994},
#  {'label': 'NEGATIVE', 'score': 0.7593432664871216},
#  {'label': 'POSITIVE', 'score': 0.9998406171798706},
#  {'label': 'POSITIVE', 'score': 0.996976375579834},
#  {'label': 'NEGATIVE', 'score': 0.9990431666374207},
#  {'label': 'POSITIVE', 'score': 0.9998606443405151},
#  {'label': 'POSITIVE', 'score': 0.999862551689148},
#  {'label': 'POSITIVE', 'score': 0.9998142123222351},
#  {'label': 'NEGATIVE', 'score': 0.9995879530906677},
#  {'label': 'NEGATIVE', 'score': 0.9997978806495667},
#  {'label': 'POSITIVE', 'score': 0.9998733997344971},
#  {'label': 'POSITIVE', 'score': 0.9983609318733215},
#  {'label': 'POSITIVE', 'score': 0.9978532195091248},
#  {'label': 'POSITIVE', 'score': 0.9998749494552612},
#  {'label': 'NEGATIVE', 'score': 0.9966557025909424},
#  {'label': 'POSITIVE', 'score': 0.9998718500137329},
#  {'label': 'POSITIVE', 'score': 0.9996289014816284},
#  {'label': 'POSITIVE', 'score': 0.9998716115951538},
#  {'label': 'NEGATIVE', 'score': 0.9914950132369995},
#  {'label': 'POSITIVE', 'score': 0.9969364404678345},
#  {'label': 'POSITIVE', 'score': 0.9994958639144897},
#  {'label': 'POSITIVE', 'score': 0.9593011736869812},
#  {'label': 'NEGATIVE', 'score': 0.9936727285385132},
#  {'label': 'NEGATIVE', 'score': 0.9328310489654541},
#  {'label': 'NEGATIVE', 'score': 0.998586893081665},
#  {'label': 'POSITIVE', 'score': 0.9998695850372314},
#  {'label': 'NEGATIVE', 'score': 0.9928025603294373},
#  {'label': 'NEGATIVE', 'score': 0.9982876181602478},
#  {'label': 'POSITIVE', 'score': 0.998909592628479},
#  {'label': 'POSITIVE', 'score': 0.9998800754547119},
#  {'label': 'POSITIVE', 'score': 0.9997493624687195},
#  {'label': 'POSITIVE', 'score': 0.9827367067337036},
#  {'label': 'NEGATIVE', 'score': 0.986968994140625},
#  {'label': 'POSITIVE', 'score': 0.9907596111297607},
#  {'label': 'POSITIVE', 'score': 0.9998480081558228},
#  {'label': 'POSITIVE', 'score': 0.8758388757705688},
#  {'label': 'POSITIVE', 'score': 0.8188163638114929},
#  {'label': 'NEGATIVE', 'score': 0.9854245781898499},
#  {'label': 'POSITIVE', 'score': 0.5353884696960449},
#  {'label': 'NEGATIVE', 'score': 0.9955034852027893},
#  {'label': 'NEGATIVE', 'score': 0.5757337808609009},
#  {'label': 'NEGATIVE', 'score': 0.9961526989936829},
#  {'label': 'POSITIVE', 'score': 0.9996833801269531},
#  {'label': 'NEGATIVE', 'score': 0.8585101366043091},
#  {'label': 'POSITIVE', 'score': 0.9901899695396423},
#  {'label': 'POSITIVE', 'score': 0.9972260594367981},
#  {'label': 'NEGATIVE', 'score': 0.5482378602027893},
#  {'label': 'POSITIVE', 'score': 0.9998149275779724},
#  {'label': 'POSITIVE', 'score': 0.7464953064918518},
#  {'label': 'POSITIVE', 'score': 0.9993495345115662},
#  {'label': 'NEGATIVE', 'score': 0.9622438549995422},
#  {'label': 'NEGATIVE', 'score': 0.9874172210693359},
#  {'label': 'NEGATIVE', 'score': 0.7749980688095093},
#  {'label': 'POSITIVE', 'score': 0.9872960448265076},
#  {'label': 'NEGATIVE', 'score': 0.9960461258888245},
#  {'label': 'POSITIVE', 'score': 0.9993597865104675},
#  {'label': 'NEGATIVE', 'score': 0.70235276222229},
#  {'label': 'POSITIVE', 'score': 0.9925317168235779},
#  {'label': 'NEGATIVE', 'score': 0.9739863276481628},
#  {'label': 'NEGATIVE', 'score': 0.9801844954490662},
#  {'label': 'NEGATIVE', 'score': 0.9991186261177063},
#  {'label': 'NEGATIVE', 'score': 0.9923704862594604},
#  {'label': 'NEGATIVE', 'score': 0.9908043146133423},
#  {'label': 'POSITIVE', 'score': 0.9921173453330994},
#  {'label': 'NEGATIVE', 'score': 0.8059688210487366},
#  {'label': 'POSITIVE', 'score': 0.9989727735519409},
#  {'label': 'NEGATIVE', 'score': 0.9826322793960571},
#  {'label': 'POSITIVE', 'score': 0.9998815059661865},
#  {'label': 'NEGATIVE', 'score': 0.5833083987236023},
#  {'label': 'NEGATIVE', 'score': 0.9285707473754883},
#  {'label': 'NEGATIVE', 'score': 0.945245623588562},
#  {'label': 'NEGATIVE', 'score': 0.997509241104126},
#  {'label': 'POSITIVE', 'score': 0.982654869556427},
#  {'label': 'NEGATIVE', 'score': 0.9054514169692993},
#  {'label': 'NEGATIVE', 'score': 0.998889148235321},
#  {'label': 'NEGATIVE', 'score': 0.988519012928009},
#  {'label': 'POSITIVE', 'score': 0.9939848780632019},
#  {'label': 'NEGATIVE', 'score': 0.9989333748817444},
#  {'label': 'NEGATIVE', 'score': 0.999622106552124},
#  {'label': 'NEGATIVE', 'score': 0.9966841340065002},
#  {'label': 'NEGATIVE', 'score': 0.9654061198234558},
#  {'label': 'POSITIVE', 'score': 0.7582744359970093},
#  {'label': 'NEGATIVE', 'score': 0.9984728693962097},
#  {'label': 'NEGATIVE', 'score': 0.9982370138168335},
#  {'label': 'NEGATIVE', 'score': 0.9996665716171265},
#  {'label': 'POSITIVE', 'score': 0.9894840121269226},
#  {'label': 'POSITIVE', 'score': 0.9997921586036682},
#  {'label': 'NEGATIVE', 'score': 0.998356282711029},
#  {'label': 'NEGATIVE', 'score': 0.9996770620346069},
#  {'label': 'POSITIVE', 'score': 0.9998095631599426},
#  {'label': 'POSITIVE', 'score': 0.8227419853210449},
#  {'label': 'POSITIVE', 'score': 0.978200376033783},
#  {'label': 'NEGATIVE', 'score': 0.9950994849205017},
#  {'label': 'POSITIVE', 'score': 0.9490106701850891},
#  {'label': 'NEGATIVE', 'score': 0.9884872436523438},
#  {'label': 'NEGATIVE', 'score': 0.999078631401062},
#  {'label': 'NEGATIVE', 'score': 0.9858237504959106},
#  {'label': 'POSITIVE', 'score': 0.9996843338012695},
#  {'label': 'NEGATIVE', 'score': 0.9912323355674744},
#  {'label': 'NEGATIVE', 'score': 0.9847466945648193},
#  {'label': 'POSITIVE', 'score': 0.9993614554405212},
#  {'label': 'NEGATIVE', 'score': 0.9988841414451599},
#  {'label': 'POSITIVE', 'score': 0.9557193517684937}]

# %%
sents2 = [i['label'] for i in sents]
sents2
# Out:
# ['NEGATIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'POSITIVE']

# %%
a = [1, 2, 3, 4]
np.where(np.array(a)==3)
# Out:
# (array([2]),)

# %%
positive_inds = np.where(np.array(sents2) == 'POSITIVE')[0]
negative_inds = np.where(np.array(sents2) == 'NEGATIVE')[0]
positive_inds
# Out:
# array([  1,   7,  13,  14,  15,  18,  19,  20,  21,  22,  23,  25,  27,
#         28,  30,  33,  34,  35,  37,  38,  41,  47,  52,  63,  64,  65,
#         66,  67,  68,  69,  70,  71,  75,  78,  79,  81,  87,  88,  89,
#         91,  96,  97,  99, 100, 102, 103, 104, 107, 108, 109, 110, 112,
#        113, 114, 116, 117, 118, 122, 125, 126, 127, 128, 130, 131, 132,
#        133, 135, 139, 141, 142, 144, 145, 146, 150, 152, 154, 160, 162,
#        164, 169, 173, 178, 182, 183, 186, 187, 188, 190, 194, 197, 199])

# %%
len(positive_inds) / 200
# Out:
# 0.455

# %%
positive_texts = ' '.join(df_tweets['Tweet'].iloc[positive_inds].tolist())
negative_texts = ' '.join(df_tweets['Tweet'].iloc[negative_inds].tolist())

# %%
import re
positive_texts2 = re.subn('htts?\S+', ' ', positive_texts)[0]
negative_texts2 = re.subn('htts?\S+', ' ', negative_texts)[0]

# %%
positive_texts2
# Out:
# 'I am thrilled to nominate Dr. @RealBenCarson as our next Secretary of the US Dept. of Housing and Urban Development…   these companies are able to move between all 50 states, with no tax or tariff being charged. Please be forewarned prior to making a very ... Our great VPE, @mike_pence, is in Louisiana campaigning for John Kennedy for US Senate. John will be a tremendous help to us in Washington. State Treasurer John Kennedy is my choice for US Senator from Louisiana. Early voting today; election next Saturday. "@TigerWoods: Can’t wait to get back out there and mix it up with the boys. ?TW #heroworldchallenge" Great to have you back Tiger - Special! The President of Taiwan CALLED ME today to wish me congratulations on winning the Presidency. Thank you! Thank you Ohio! Together, we made history ? and now, the real work begins. America will start winning again!…   Heading to U.S. Bank Arena in Cincinnati, Ohio for a 7pm rally. Join me! Tickets:   Getting ready to leave for the Great State of Indiana and meet the hard working and wonderful people of Carrier A.C. My thoughts and prayers are with those affected by the tragic storms and tornadoes in the Southeastern United States. Stay safe! Look forward to going to Indiana tomorrow in order to be with the great workers of Carrier. They will sell many air conditioners! RT @DanScavino: Great interview on @foxandfriends by @SteveDoocy w/ Carrier employee- who has a message for #PEOTUS @realDonaldTrump & #VPE… Join me in Cincinnati, Ohio tomorrow evening at 7:00pm. I am grateful for all of your support. THANK YOU! Tickets:…   Hence, legal documents are being crafted which take me completely out of business operations. The Presidency is a far more important task! great business in total in order to fully focus on running the country in order to MAKE AMERICA GREAT AGAIN! While I am not mandated to .... Big day on Thursday for Indiana and the great workers of that wonderful state.We will keep our companies and jobs in the U.S. Thanks Carrier I will be going to Indiana on Thursday to make a major announcement concerning Carrier A.C. staying in Indianapolis. Great deal for workers! \'President-Elect Donald J. Trump Nominates Elaine Chao as Secretary of the Department of Transportation\'   RT @DanScavino: Back to Cincinnati, Ohio this Thursday (12/1/16) at 7pm for #PEOTUS @realDonaldTrump\'s #ThankYouTour2016! Join us!   My thoughts and prayers are with the great people of Tennessee during these terrible wildfires. Stay safe! The Great State of Michigan was just certified as a Trump WIN giving all of our MAKE AMERICA GREAT AGAIN supporters another victory - 306! Just met with General Petraeus--was very impressed! In addition to winning the Electoral College in a landslide, I won the popular vote if you deduct the millions of people who voted illegally I am working hard, even on Thanksgiving, trying to get Carrier A.C. Company to stay in the U.S. (Indiana). MAKING PROGRESS - Will know soon! Happy Thanksgiving to everyone. We will, together, MAKE AMERICA GREAT AGAIN! Let us give thanks for all that we have, and let us boldly face the exciting new frontiers that lie ahead. Happy Th…   Bus crash in Tennessee so sad & so terrible. Condolences to all family members and loved ones. These beautiful children will be remembered! I am seriously considering Dr. Ben Carson as the head of HUD. I\'ve gotten to know him well--he\'s a greatly talented person who loves people! The meeting with the @nytimes is back on at 12:30 today. Look forward to it! \'Jeff Sessions, a Fitting Selection for Attorney General\'   \'President-elect Donald J. Trump\'s CIA Director Garners Praise\'     Great meetings will take place today at Trump Tower concerning the formation of the people who will run our government for the next 8 years. Many people would like to see @Nigel_Farage represent Great Britain as their Ambassador to the United States. He would do a great job! I have always had a good relationship with Chuck Schume ...

# %%
wordcloud = WordCloud(background_color="white",
    width=800,height=600).generate(positive_texts2)

wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=800x600 at 0x7F0F4D791450>

# %%
wordcloud = WordCloud(background_color="white",
    width=800,height=600).generate(negative_texts2)

wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=800x600 at 0x7F0F4DE34A90>

# %%
# Challenge

# Download the file first!

# !wget https://github.com/dgod1028/Research/raw/main/data/sents.pickle # download file
# Out:
# --2023-06-30 01:37:13--  https://github.com/dgod1028/Research/raw/main/data/sents.pickle
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dgod1028/Research/main/data/sents.pickle [following]
# --2023-06-30 01:37:13--  https://raw.githubusercontent.com/dgod1028/Research/main/data/sents.pickle
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 571660 (558K) [application/octet-stream]
# Saving to: ‘sents.pickle.1’
#
# sents.pickle.1      100%[===================>] 558.26K  --.-KB/s    in 0.04s
#
# 2023-06-30 01:37:14 (12.8 MB/s) - ‘sents.pickle.1’ saved [571660/571660]

# %%
import pickle
all_sents = pickle.load(open('sents.pickle','rb'))
all_sents
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9997783303260803},
#  {'label': 'POSITIVE', 'score': 0.9984751343727112},
#  {'label': 'NEGATIVE', 'score': 0.9921970367431641},
#  {'label': 'NEGATIVE', 'score': 0.9995797276496887},
#  {'label': 'NEGATIVE', 'score': 0.9866687059402466},
#  {'label': 'NEGATIVE', 'score': 0.9997541308403015},
#  {'label': 'NEGATIVE', 'score': 0.9813768267631531},
#  {'label': 'POSITIVE', 'score': 0.9950882792472839},
#  {'label': 'NEGATIVE', 'score': 0.9952906370162964},
#  {'label': 'NEGATIVE', 'score': 0.9938435554504395},
#  {'label': 'NEGATIVE', 'score': 0.9994345307350159},
#  {'label': 'NEGATIVE', 'score': 0.9659892320632935},
#  {'label': 'NEGATIVE', 'score': 0.9989173412322998},
#  {'label': 'POSITIVE', 'score': 0.9996168613433838},
#  {'label': 'POSITIVE', 'score': 0.994712769985199},
#  {'label': 'POSITIVE', 'score': 0.9995182752609253},
#  {'label': 'NEGATIVE', 'score': 0.9994326233863831},
#  {'label': 'NEGATIVE', 'score': 0.9989601373672485},
#  {'label': 'POSITIVE', 'score': 0.9998445510864258},
#  {'label': 'POSITIVE', 'score': 0.9997283816337585},
#  {'label': 'POSITIVE', 'score': 0.6528465747833252},
#  {'label': 'POSITIVE', 'score': 0.9998102784156799},
#  {'label': 'POSITIVE', 'score': 0.9870457649230957},
#  {'label': 'POSITIVE', 'score': 0.9996875524520874},
#  {'label': 'NEGATIVE', 'score': 0.9490075707435608},
#  {'label': 'POSITIVE', 'score': 0.9931352138519287},
#  {'label': 'NEGATIVE', 'score': 0.7693294286727905},
#  {'label': 'POSITIVE', 'score': 0.9996815919876099},
#  {'label': 'POSITIVE', 'score': 0.985383927822113},
#  {'label': 'NEGATIVE', 'score': 0.9452864527702332},
#  {'label': 'POSITIVE', 'score': 0.9997060894966125},
#  {'label': 'NEGATIVE', 'score': 0.6497567892074585},
#  {'label': 'NEGATIVE', 'score': 0.9934731125831604},
#  {'label': 'POSITIVE', 'score': 0.9998644590377808},
#  {'label': 'POSITIVE', 'score': 0.9974648952484131},
#  {'label': 'POSITIVE', 'score': 0.6550751328468323},
#  {'label': 'NEGATIVE', 'score': 0.9726647734642029},
#  {'label': 'POSITIVE', 'score': 0.9321538209915161},
#  {'label': 'POSITIVE', 'score': 0.9928432703018188},
#  {'label': 'NEGATIVE', 'score': 0.9987145662307739},
#  {'label': 'NEGATIVE', 'score': 0.9995736479759216},
#  {'label': 'POSITIVE', 'score': 0.9993427395820618},
#  {'label': 'NEGATIVE', 'score': 0.9994857311248779},
#  {'label': 'NEGATIVE', 'score': 0.9853712320327759},
#  {'label': 'NEGATIVE', 'score': 0.9996145963668823},
#  {'label': 'NEGATIVE', 'score': 0.9994233846664429},
#  {'label': 'NEGATIVE', 'score': 0.9030430316925049},
#  {'label': 'POSITIVE', 'score': 0.9998190999031067},
#  {'label': 'NEGATIVE', 'score': 0.9992786049842834},
#  {'label': 'NEGATIVE', 'score': 0.999313235282898},
#  {'label': 'NEGATIVE', 'score': 0.7645199298858643},
#  {'label': 'NEGATIVE', 'score': 0.9993497729301453},
#  {'label': 'POSITIVE', 'score': 0.9995158910751343},
#  {'label': 'NEGATIVE', 'score': 0.9636472463607788},
#  {'label': 'NEGATIVE', 'score': 0.9911544322967529},
#  {'label': 'NEGATIVE', 'score': 0.9966493248939514},
#  {'label': 'NEGATIVE', 'score': 0.9971871972084045},
#  {'label': 'NEGATIVE', 'score': 0.9499409198760986},
#  {'label': 'NEGATIVE', 'score': 0.9984927177429199},
#  {'label': 'NEGATIVE', 'score': 0.9987892508506775},
#  {'label': 'NEGATIVE', 'score': 0.9951838850975037},
#  {'label': 'NEGATIVE', 'score': 0.9997169375419617},
#  {'label': 'NEGATIVE', 'score': 0.9974448680877686},
#  {'label': 'POSITIVE', 'score': 0.9960261583328247},
#  {'label': 'POSITIVE', 'score': 0.9998682737350464},
#  {'label': 'POSITIVE', 'score': 0.9997803568840027},
#  {'label': 'POSITIVE', 'score': 0.996793806552887},
#  {'label': 'POSITIVE', 'score': 0.9997791647911072},
#  {'label': 'POSITIVE', 'score': 0.9998168349266052},
#  {'label': 'POSITIVE', 'score': 0.9961389899253845},
#  {'label': 'POSITIVE', 'score': 0.997657060623169},
#  {'label': 'POSITIVE', 'score': 0.9996347427368164},
#  {'label': 'NEGATIVE', 'score': 0.9993690848350525},
#  {'label': 'NEGATIVE', 'score': 0.998572587966919},
#  {'label': 'NEGATIVE', 'score': 0.999765932559967},
#  {'label': 'POSITIVE', 'score': 0.9997844099998474},
#  {'label': 'NEGATIVE', 'score': 0.8915016651153564},
#  {'label': 'NEGATIVE', 'score': 0.9911250472068787},
#  {'label': 'POSITIVE', 'score': 0.9998466968536377},
#  {'label': 'POSITIVE', 'score': 0.9998338222503662},
#  {'label': 'NEGATIVE', 'score': 0.999725878238678},
#  {'label': 'POSITIVE', 'score': 0.9995439648628235},
#  {'label': 'NEGATIVE', 'score': 0.9992456436157227},
#  {'label': 'NEGATIVE', 'score': 0.9464575052261353},
#  {'label': 'NEGATIVE', 'score': 0.9995085000991821},
#  {'label': 'NEGATIVE', 'score': 0.9848068952560425},
#  {'label': 'NEGATIVE', 'score': 0.763590395450592},
#  {'label': 'POSITIVE', 'score': 0.9998242259025574},
#  {'label': 'POSITIVE', 'score': 0.9405121803283691},
#  {'label': 'POSITIVE', 'score': 0.9989691972732544},
#  {'label': 'NEGATIVE', 'score': 0.9721603393554688},
#  {'label': 'POSITIVE', 'score': 0.9997723698616028},
#  {'label': 'NEGATIVE', 'score': 0.7244531512260437},
#  {'label': 'NEGATIVE', 'score': 0.5133758187294006},
#  {'label': 'NEGATIVE', 'score': 0.9862646460533142},
#  {'label': 'NEGATIVE', 'score': 0.9988806843757629},
#  {'label': 'POSITIVE', 'score': 0.617595374584198},
#  {'label': 'POSITIVE', 'score': 0.9996817111968994},
#  {'label': 'NEGATIVE', 'score': 0.7593432068824768},
#  {'label': 'POSITIVE', 'score': 0.9998406171798706},
#  {'label': 'POSITIVE', 'score': 0.996976375579834},
#  {'label': 'NEGATIVE', 'score': 0.9990431666374207},
#  {'label': 'POSITIVE', 'score': 0.9998606443405151},
#  {'label': 'POSITIVE', 'score': 0.999862551689148},
#  {'label': 'POSITIVE', 'score': 0.9998142123222351},
#  {'label': 'NEGATIVE', 'score': 0.9995879530906677},
#  {'label': 'NEGATIVE', 'score': 0.9997978806495667},
#  {'label': 'POSITIVE', 'score': 0.9998733997344971},
#  {'label': 'POSITIVE', 'score': 0.9983609318733215},
#  {'label': 'POSITIVE', 'score': 0.9978532195091248},
#  {'label': 'POSITIVE', 'score': 0.9998749494552612},
#  {'label': 'NEGATIVE', 'score': 0.9966557025909424},
#  {'label': 'POSITIVE', 'score': 0.9998718500137329},
#  {'label': 'POSITIVE', 'score': 0.9996289014816284},
#  {'label': 'POSITIVE', 'score': 0.9998716115951538},
#  {'label': 'NEGATIVE', 'score': 0.9914950132369995},
#  {'label': 'POSITIVE', 'score': 0.9969364404678345},
#  {'label': 'POSITIVE', 'score': 0.9994958639144897},
#  {'label': 'POSITIVE', 'score': 0.9593013525009155},
#  {'label': 'NEGATIVE', 'score': 0.9936727285385132},
#  {'label': 'NEGATIVE', 'score': 0.9328311085700989},
#  {'label': 'NEGATIVE', 'score': 0.998586893081665},
#  {'label': 'POSITIVE', 'score': 0.9998695850372314},
#  {'label': 'NEGATIVE', 'score': 0.9928025603294373},
#  {'label': 'NEGATIVE', 'score': 0.9982876181602478},
#  {'label': 'POSITIVE', 'score': 0.998909592628479},
#  {'label': 'POSITIVE', 'score': 0.9998800754547119},
#  {'label': 'POSITIVE', 'score': 0.9997493624687195},
#  {'label': 'POSITIVE', 'score': 0.9827367067337036},
#  {'label': 'NEGATIVE', 'score': 0.986968994140625},
#  {'label': 'POSITIVE', 'score': 0.9907596111297607},
#  {'label': 'POSITIVE', 'score': 0.9998480081558228},
#  {'label': 'POSITIVE', 'score': 0.8758388161659241},
#  {'label': 'POSITIVE', 'score': 0.8188148736953735},
#  {'label': 'NEGATIVE', 'score': 0.9854245781898499},
#  {'label': 'POSITIVE', 'score': 0.5353878140449524},
#  {'label': 'NEGATIVE', 'score': 0.9955034852027893},
#  {'label': 'NEGATIVE', 'score': 0.5757318139076233},
#  {'label': 'NEGATIVE', 'score': 0.9961526989936829},
#  {'label': 'POSITIVE', 'score': 0.9996833801269531},
#  {'label': 'NEGATIVE', 'score': 0.8585092425346375},
#  {'label': 'POSITIVE', 'score': 0.9901899695396423},
#  {'label': 'POSITIVE', 'score': 0.9972260594367981},
#  {'label': 'NEGATIVE', 'score': 0.548237144947052},
#  {'label': 'POSITIVE', 'score': 0.9998149275779724},
#  {'label': 'POSITIVE', 'score': 0.7464936375617981},
#  {'label': 'POSITIVE', 'score': 0.9993495345115662},
#  {'label': 'NEGATIVE', 'score': 0.9622438549995422},
#  {'label': 'NEGATIVE', 'score': 0.9874172210693359},
#  {'label': 'NEGATIVE', 'score': 0.7749983072280884},
#  {'label': 'POSITIVE', 'score': 0.9872960448265076},
#  {'label': 'NEGATIVE', 'score': 0.9960461258888245},
#  {'label': 'POSITIVE', 'score': 0.9993597865104675},
#  {'label': 'NEGATIVE', 'score': 0.7023537158966064},
#  {'label': 'POSITIVE', 'score': 0.9925318360328674},
#  {'label': 'NEGATIVE', 'score': 0.9739863276481628},
#  {'label': 'NEGATIVE', 'score': 0.9801844954490662},
#  {'label': 'NEGATIVE', 'score': 0.9991186261177063},
#  {'label': 'NEGATIVE', 'score': 0.9923704862594604},
#  {'label': 'NEGATIVE', 'score': 0.9908043146133423},
#  {'label': 'POSITIVE', 'score': 0.9921173453330994},
#  {'label': 'NEGATIVE', 'score': 0.8059697151184082},
#  {'label': 'POSITIVE', 'score': 0.9989727735519409},
#  {'label': 'NEGATIVE', 'score': 0.9826322793960571},
#  {'label': 'POSITIVE', 'score': 0.9998815059661865},
#  {'label': 'NEGATIVE', 'score': 0.5833100080490112},
#  {'label': 'NEGATIVE', 'score': 0.9285704493522644},
#  {'label': 'NEGATIVE', 'score': 0.9452457427978516},
#  {'label': 'NEGATIVE', 'score': 0.997509241104126},
#  {'label': 'POSITIVE', 'score': 0.9826547503471375},
#  {'label': 'NEGATIVE', 'score': 0.9054515957832336},
#  {'label': 'NEGATIVE', 'score': 0.998889148235321},
#  {'label': 'NEGATIVE', 'score': 0.988519012928009},
#  {'label': 'POSITIVE', 'score': 0.9939849972724915},
#  {'label': 'NEGATIVE', 'score': 0.9989333748817444},
#  {'label': 'NEGATIVE', 'score': 0.999622106552124},
#  {'label': 'NEGATIVE', 'score': 0.9966841340065002},
#  {'label': 'NEGATIVE', 'score': 0.9654061198234558},
#  {'label': 'POSITIVE', 'score': 0.7582757472991943},
#  {'label': 'NEGATIVE', 'score': 0.9984728693962097},
#  {'label': 'NEGATIVE', 'score': 0.9982370138168335},
#  {'label': 'NEGATIVE', 'score': 0.9996665716171265},
#  {'label': 'POSITIVE', 'score': 0.9894838929176331},
#  {'label': 'POSITIVE', 'score': 0.9997921586036682},
#  {'label': 'NEGATIVE', 'score': 0.998356282711029},
#  {'label': 'NEGATIVE', 'score': 0.9996770620346069},
#  {'label': 'POSITIVE', 'score': 0.9998095631599426},
#  {'label': 'POSITIVE', 'score': 0.8227440714836121},
#  {'label': 'POSITIVE', 'score': 0.978200376033783},
#  {'label': 'NEGATIVE', 'score': 0.9950994849205017},
#  {'label': 'POSITIVE', 'score': 0.9490101337432861},
#  {'label': 'NEGATIVE', 'score': 0.9884872436523438},
#  {'label': 'NEGATIVE', 'score': 0.999078631401062},
#  {'label': 'NEGATIVE', 'score': 0.9858237504959106},
#  {'label': 'POSITIVE', 'score': 0.9996843338012695},
#  {'label': 'NEGATIVE', 'score': 0.9912323355674744},
#  {'label': 'NEGATIVE', 'score': 0.9847466945648193},
#  {'label': 'POSITIVE', 'score': 0.9993614554405212},
#  {'label': 'NEGATIVE', 'score': 0.9988841414451599},
#  {'label': 'POSITIVE', 'score': 0.9557192921638489},
#  {'label': 'NEGATIVE', 'score': 0.9756693243980408},
#  {'label': 'NEGATIVE', 'score': 0.953738808631897},
#  {'label': 'POSITIVE', 'score': 0.744075357913971},
#  {'label': 'POSITIVE', 'score': 0.9642114639282227},
#  {'label': 'NEGATIVE', 'score': 0.99930739402771},
#  {'label': 'NEGATIVE', 'score': 0.9940485954284668},
#  {'label': 'NEGATIVE', 'score': 0.9885804057121277},
#  {'label': 'NEGATIVE', 'score': 0.9961040019989014},
#  {'label': 'NEGATIVE', 'score': 0.7145923376083374},
#  {'label': 'NEGATIVE', 'score': 0.643535315990448},
#  {'label': 'POSITIVE', 'score': 0.9998266100883484},
#  {'label': 'POSITIVE', 'score': 0.9239810705184937},
#  {'label': 'NEGATIVE', 'score': 0.9995668530464172},
#  {'label': 'NEGATIVE', 'score': 0.9676874876022339},
#  {'label': 'NEGATIVE', 'score': 0.9987340569496155},
#  {'label': 'POSITIVE', 'score': 0.8766060471534729},
#  {'label': 'NEGATIVE', 'score': 0.9997298121452332},
#  {'label': 'NEGATIVE', 'score': 0.9479397535324097},
#  {'label': 'NEGATIVE', 'score': 0.9877278804779053},
#  {'label': 'POSITIVE', 'score': 0.9913607239723206},
#  {'label': 'NEGATIVE', 'score': 0.9551383852958679},
#  {'label': 'POSITIVE', 'score': 0.997803270816803},
#  {'label': 'NEGATIVE', 'score': 0.9963210821151733},
#  {'label': 'NEGATIVE', 'score': 0.9669234156608582},
#  {'label': 'POSITIVE', 'score': 0.9814233183860779},
#  {'label': 'POSITIVE', 'score': 0.9975712895393372},
#  {'label': 'POSITIVE', 'score': 0.9978583455085754},
#  {'label': 'POSITIVE', 'score': 0.9965795874595642},
#  {'label': 'POSITIVE', 'score': 0.9609965682029724},
#  {'label': 'NEGATIVE', 'score': 0.9994645714759827},
#  {'label': 'POSITIVE', 'score': 0.9954272508621216},
#  {'label': 'POSITIVE', 'score': 0.8341531753540039},
#  {'label': 'POSITIVE', 'score': 0.9990826845169067},
#  {'label': 'POSITIVE', 'score': 0.9996086955070496},
#  {'label': 'POSITIVE', 'score': 0.9997610449790955},
#  {'label': 'NEGATIVE', 'score': 0.9953892230987549},
#  {'label': 'NEGATIVE', 'score': 0.9887209534645081},
#  {'label': 'NEGATIVE', 'score': 0.6473860740661621},
#  {'label': 'NEGATIVE', 'score': 0.9706780910491943},
#  {'label': 'NEGATIVE', 'score': 0.98973149061203},
#  {'label': 'NEGATIVE', 'score': 0.8251175880432129},
#  {'label': 'POSITIVE', 'score': 0.9961749315261841},
#  {'label': 'NEGATIVE', 'score': 0.9747146964073181},
#  {'label': 'POSITIVE', 'score': 0.9918569326400757},
#  {'label': 'NEGATIVE', 'score': 0.9973500967025757},
#  {'label': 'NEGATIVE', 'score': 0.8588335514068604},
#  {'label': 'NEGATIVE', 'score': 0.9972735047340393},
#  {'label': 'NEGATIVE', 'score': 0.9268673062324524},
#  {'label': 'NEGATIVE', 'score': 0.999404788017273},
#  {'label': 'NEGATIVE', 'score': 0.9754508137702942},
#  {'label': 'NEGATIVE', 'score': 0.9989332556724548},
#  {'label': 'NEGATIVE', 'score': 0.9977275729179382},
#  {'label': 'POSITIVE', 'score': 0.8541759252548218},
#  {'label': 'NEGATIVE', 'score': 0.9778946042060852},
#  {'label': 'NEGATIVE', 'score': 0.9948632121086121},
#  {'label': 'NEGATIVE', 'score': 0.9615813493728638},
#  {'label': 'POSITIVE', 'score': 0.9969688057899475},
#  {'label': 'POSITIVE', 'score': 0.9965229034423828},
#  {'label': 'NEGATIVE', 'score': 0.9979598522186279},
#  {'label': 'NEGATIVE', 'score': 0.9903506636619568},
#  {'label': 'POSITIVE', 'score': 0.9942741990089417},
#  {'label': 'NEGATIVE', 'score': 0.8241203427314758},
#  {'label': 'NEGATIVE', 'score': 0.9162322282791138},
#  {'label': 'NEGATIVE', 'score': 0.9913401007652283},
#  {'label': 'NEGATIVE', 'score': 0.9349410533905029},
#  {'label': 'POSITIVE', 'score': 0.9958392381668091},
#  {'label': 'NEGATIVE', 'score': 0.9453421831130981},
#  {'label': 'NEGATIVE', 'score': 0.9923698902130127},
#  {'label': 'NEGATIVE', 'score': 0.998166024684906},
#  {'label': 'NEGATIVE', 'score': 0.9994148015975952},
#  {'label': 'NEGATIVE', 'score': 0.9997206330299377},
#  {'label': 'POSITIVE', 'score': 0.974699854850769},
#  {'label': 'POSITIVE', 'score': 0.9994627833366394},
#  {'label': 'POSITIVE', 'score': 0.9990108013153076},
#  {'label': 'NEGATIVE', 'score': 0.999591052532196},
#  {'label': 'NEGATIVE', 'score': 0.9800735116004944},
#  {'label': 'POSITIVE', 'score': 0.5162782669067383},
#  {'label': 'POSITIVE', 'score': 0.9996496438980103},
#  {'label': 'POSITIVE', 'score': 0.5592532157897949},
#  {'label': 'NEGATIVE', 'score': 0.9742075800895691},
#  {'label': 'POSITIVE', 'score': 0.9964966177940369},
#  {'label': 'POSITIVE', 'score': 0.9981630444526672},
#  {'label': 'NEGATIVE', 'score': 0.9971928000450134},
#  {'label': 'NEGATIVE', 'score': 0.9996066689491272},
#  {'label': 'POSITIVE', 'score': 0.9918501973152161},
#  {'label': 'NEGATIVE', 'score': 0.9997267127037048},
#  {'label': 'NEGATIVE', 'score': 0.9854462146759033},
#  {'label': 'NEGATIVE', 'score': 0.9997451901435852},
#  {'label': 'NEGATIVE', 'score': 0.9898188710212708},
#  {'label': 'NEGATIVE', 'score': 0.9903180599212646},
#  {'label': 'POSITIVE', 'score': 0.9996153116226196},
#  {'label': 'NEGATIVE', 'score': 0.9386487603187561},
#  {'label': 'NEGATIVE', 'score': 0.9989632368087769},
#  {'label': 'NEGATIVE', 'score': 0.9991170763969421},
#  {'label': 'POSITIVE', 'score': 0.9996343851089478},
#  {'label': 'POSITIVE', 'score': 0.999617338180542},
#  {'label': 'NEGATIVE', 'score': 0.8231132626533508},
#  {'label': 'NEGATIVE', 'score': 0.9980670809745789},
#  {'label': 'NEGATIVE', 'score': 0.989368736743927},
#  {'label': 'NEGATIVE', 'score': 0.9597049355506897},
#  {'label': 'NEGATIVE', 'score': 0.9958835244178772},
#  {'label': 'POSITIVE', 'score': 0.5835659503936768},
#  {'label': 'POSITIVE', 'score': 0.9993569254875183},
#  {'label': 'NEGATIVE', 'score': 0.9919247031211853},
#  {'label': 'NEGATIVE', 'score': 0.8436674475669861},
#  {'label': 'NEGATIVE', 'score': 0.9993259906768799},
#  {'label': 'NEGATIVE', 'score': 0.9945088028907776},
#  {'label': 'NEGATIVE', 'score': 0.999071478843689},
#  {'label': 'NEGATIVE', 'score': 0.983601987361908},
#  {'label': 'NEGATIVE', 'score': 0.997022807598114},
#  {'label': 'POSITIVE', 'score': 0.988341748714447},
#  {'label': 'NEGATIVE', 'score': 0.991104781627655},
#  {'label': 'NEGATIVE', 'score': 0.9716297388076782},
#  {'label': 'NEGATIVE', 'score': 0.9785832166671753},
#  {'label': 'POSITIVE', 'score': 0.8475750684738159},
#  {'label': 'NEGATIVE', 'score': 0.9997121691703796},
#  {'label': 'NEGATIVE', 'score': 0.9981934428215027},
#  {'label': 'NEGATIVE', 'score': 0.9005210995674133},
#  {'label': 'NEGATIVE', 'score': 0.9982896447181702},
#  {'label': 'NEGATIVE', 'score': 0.9941627383232117},
#  {'label': 'POSITIVE', 'score': 0.9879831075668335},
#  {'label': 'NEGATIVE', 'score': 0.7362682819366455},
#  {'label': 'NEGATIVE', 'score': 0.9888821244239807},
#  {'label': 'NEGATIVE', 'score': 0.820679783821106},
#  {'label': 'NEGATIVE', 'score': 0.9941773414611816},
#  {'label': 'NEGATIVE', 'score': 0.9786900877952576},
#  {'label': 'NEGATIVE', 'score': 0.9989895224571228},
#  {'label': 'NEGATIVE', 'score': 0.9284020066261292},
#  {'label': 'NEGATIVE', 'score': 0.9986807703971863},
#  {'label': 'POSITIVE', 'score': 0.9940637946128845},
#  {'label': 'NEGATIVE', 'score': 0.9990853071212769},
#  {'label': 'POSITIVE', 'score': 0.9830016493797302},
#  {'label': 'NEGATIVE', 'score': 0.9882619976997375},
#  {'label': 'NEGATIVE', 'score': 0.9894640445709229},
#  {'label': 'NEGATIVE', 'score': 0.9682678580284119},
#  {'label': 'POSITIVE', 'score': 0.9056896567344666},
#  {'label': 'NEGATIVE', 'score': 0.9539561867713928},
#  {'label': 'NEGATIVE', 'score': 0.9948973059654236},
#  {'label': 'NEGATIVE', 'score': 0.9991872906684875},
#  {'label': 'POSITIVE', 'score': 0.9753369688987732},
#  {'label': 'POSITIVE', 'score': 0.9997900128364563},
#  {'label': 'NEGATIVE', 'score': 0.8660356998443604},
#  {'label': 'POSITIVE', 'score': 0.998112678527832},
#  {'label': 'NEGATIVE', 'score': 0.9990260601043701},
#  {'label': 'NEGATIVE', 'score': 0.8294757008552551},
#  {'label': 'NEGATIVE', 'score': 0.9896013140678406},
#  {'label': 'NEGATIVE', 'score': 0.9984638690948486},
#  {'label': 'NEGATIVE', 'score': 0.9991235136985779},
#  {'label': 'POSITIVE', 'score': 0.9632025361061096},
#  {'label': 'POSITIVE', 'score': 0.9994301199913025},
#  {'label': 'NEGATIVE', 'score': 0.949267566204071},
#  {'label': 'NEGATIVE', 'score': 0.982711136341095},
#  {'label': 'POSITIVE', 'score': 0.9979250431060791},
#  {'label': 'POSITIVE', 'score': 0.9998784065246582},
#  {'label': 'NEGATIVE', 'score': 0.9997820258140564},
#  {'label': 'NEGATIVE', 'score': 0.9875510334968567},
#  {'label': 'NEGATIVE', 'score': 0.993161678314209},
#  {'label': 'POSITIVE', 'score': 0.9993157386779785},
#  {'label': 'POSITIVE', 'score': 0.9146276116371155},
#  {'label': 'NEGATIVE', 'score': 0.9975282549858093},
#  {'label': 'NEGATIVE', 'score': 0.9749899506568909},
#  {'label': 'NEGATIVE', 'score': 0.8646551966667175},
#  {'label': 'NEGATIVE', 'score': 0.9911175966262817},
#  {'label': 'POSITIVE', 'score': 0.9911090135574341},
#  {'label': 'NEGATIVE', 'score': 0.9979974627494812},
#  {'label': 'NEGATIVE', 'score': 0.9704596996307373},
#  {'label': 'NEGATIVE', 'score': 0.9979027509689331},
#  {'label': 'NEGATIVE', 'score': 0.9977896213531494},
#  {'label': 'POSITIVE', 'score': 0.9969511032104492},
#  {'label': 'POSITIVE', 'score': 0.9984198808670044},
#  {'label': 'NEGATIVE', 'score': 0.9995470643043518},
#  {'label': 'NEGATIVE', 'score': 0.9909499287605286},
#  {'label': 'NEGATIVE', 'score': 0.9938448667526245},
#  {'label': 'POSITIVE', 'score': 0.9725832939147949},
#  {'label': 'POSITIVE', 'score': 0.9998685121536255},
#  {'label': 'NEGATIVE', 'score': 0.9917536973953247},
#  {'label': 'POSITIVE', 'score': 0.9825165271759033},
#  {'label': 'POSITIVE', 'score': 0.9979074001312256},
#  {'label': 'POSITIVE', 'score': 0.9994875192642212},
#  {'label': 'NEGATIVE', 'score': 0.9927914142608643},
#  {'label': 'NEGATIVE', 'score': 0.9981312155723572},
#  {'label': 'NEGATIVE', 'score': 0.9989763498306274},
#  {'label': 'POSITIVE', 'score': 0.5811660885810852},
#  {'label': 'NEGATIVE', 'score': 0.9985804557800293},
#  {'label': 'NEGATIVE', 'score': 0.8636383414268494},
#  {'label': 'NEGATIVE', 'score': 0.9816557765007019},
#  {'label': 'NEGATIVE', 'score': 0.9991970658302307},
#  {'label': 'NEGATIVE', 'score': 0.9970117807388306},
#  {'label': 'NEGATIVE', 'score': 0.9995303153991699},
#  {'label': 'NEGATIVE', 'score': 0.9547001123428345},
#  {'label': 'NEGATIVE', 'score': 0.999313235282898},
#  {'label': 'NEGATIVE', 'score': 0.9991940855979919},
#  {'label': 'NEGATIVE', 'score': 0.9974699020385742},
#  {'label': 'NEGATIVE', 'score': 0.9983822107315063},
#  {'label': 'NEGATIVE', 'score': 0.9967318773269653},
#  {'label': 'NEGATIVE', 'score': 0.9992234706878662},
#  {'label': 'NEGATIVE', 'score': 0.9996944665908813},
#  {'label': 'NEGATIVE', 'score': 0.9881382584571838},
#  {'label': 'NEGATIVE', 'score': 0.9994810223579407},
#  {'label': 'NEGATIVE', 'score': 0.998279333114624},
#  {'label': 'NEGATIVE', 'score': 0.9924341440200806},
#  {'label': 'NEGATIVE', 'score': 0.9974045157432556},
#  {'label': 'NEGATIVE', 'score': 0.9191020131111145},
#  {'label': 'NEGATIVE', 'score': 0.9988909363746643},
#  {'label': 'NEGATIVE', 'score': 0.9993556141853333},
#  {'label': 'NEGATIVE', 'score': 0.5710663199424744},
#  {'label': 'NEGATIVE', 'score': 0.9750300645828247},
#  {'label': 'NEGATIVE', 'score': 0.8641178607940674},
#  {'label': 'NEGATIVE', 'score': 0.9824851751327515},
#  {'label': 'NEGATIVE', 'score': 0.967957615852356},
#  {'label': 'NEGATIVE', 'score': 0.9349547028541565},
#  {'label': 'NEGATIVE', 'score': 0.9965373277664185},
#  {'label': 'NEGATIVE', 'score': 0.9889708757400513},
#  {'label': 'NEGATIVE', 'score': 0.9989308714866638},
#  {'label': 'NEGATIVE', 'score': 0.9989596605300903},
#  {'label': 'NEGATIVE', 'score': 0.9921656847000122},
#  {'label': 'NEGATIVE', 'score': 0.999406099319458},
#  {'label': 'NEGATIVE', 'score': 0.9936063289642334},
#  {'label': 'NEGATIVE', 'score': 0.9991191029548645},
#  {'label': 'NEGATIVE', 'score': 0.9303579926490784},
#  {'label': 'NEGATIVE', 'score': 0.9993937015533447},
#  {'label': 'NEGATIVE', 'score': 0.9597238302230835},
#  {'label': 'NEGATIVE', 'score': 0.9852285385131836},
#  {'label': 'NEGATIVE', 'score': 0.9467199444770813},
#  {'label': 'NEGATIVE', 'score': 0.9921615719795227},
#  {'label': 'NEGATIVE', 'score': 0.9987441301345825},
#  {'label': 'NEGATIVE', 'score': 0.9913977384567261},
#  {'label': 'NEGATIVE', 'score': 0.5854584574699402},
#  {'label': 'NEGATIVE', 'score': 0.9098203182220459},
#  {'label': 'NEGATIVE', 'score': 0.9827835559844971},
#  {'label': 'NEGATIVE', 'score': 0.9908961653709412},
#  {'label': 'NEGATIVE', 'score': 0.9968398809432983},
#  {'label': 'NEGATIVE', 'score': 0.9860926270484924},
#  {'label': 'NEGATIVE', 'score': 0.9960551261901855},
#  {'label': 'NEGATIVE', 'score': 0.998065173625946},
#  {'label': 'NEGATIVE', 'score': 0.9934763312339783},
#  {'label': 'NEGATIVE', 'score': 0.9939226508140564},
#  {'label': 'NEGATIVE', 'score': 0.9916764497756958},
#  {'label': 'POSITIVE', 'score': 0.9996963739395142},
#  {'label': 'POSITIVE', 'score': 0.9950768351554871},
#  {'label': 'NEGATIVE', 'score': 0.991421639919281},
#  {'label': 'NEGATIVE', 'score': 0.9971392154693604},
#  {'label': 'NEGATIVE', 'score': 0.9969977140426636},
#  {'label': 'NEGATIVE', 'score': 0.985964298248291},
#  {'label': 'NEGATIVE', 'score': 0.9894706010818481},
#  {'label': 'NEGATIVE', 'score': 0.9946354031562805},
#  {'label': 'NEGATIVE', 'score': 0.999283492565155},
#  {'label': 'NEGATIVE', 'score': 0.9997252821922302},
#  {'label': 'NEGATIVE', 'score': 0.9985464215278625},
#  {'label': 'NEGATIVE', 'score': 0.9962483048439026},
#  {'label': 'NEGATIVE', 'score': 0.9987322688102722},
#  {'label': 'NEGATIVE', 'score': 0.9947649240493774},
#  {'label': 'NEGATIVE', 'score': 0.9990181922912598},
#  {'label': 'NEGATIVE', 'score': 0.9984997510910034},
#  {'label': 'NEGATIVE', 'score': 0.999370276927948},
#  {'label': 'NEGATIVE', 'score': 0.9939005374908447},
#  {'label': 'NEGATIVE', 'score': 0.9995959401130676},
#  {'label': 'NEGATIVE', 'score': 0.9919103980064392},
#  {'label': 'NEGATIVE', 'score': 0.9990684390068054},
#  {'label': 'POSITIVE', 'score': 0.9800398349761963},
#  {'label': 'NEGATIVE', 'score': 0.9951838850975037},
#  {'label': 'NEGATIVE', 'score': 0.9986432194709778},
#  {'label': 'NEGATIVE', 'score': 0.9954327344894409},
#  {'label': 'POSITIVE', 'score': 0.6016028523445129},
#  {'label': 'NEGATIVE', 'score': 0.9968888163566589},
#  {'label': 'NEGATIVE', 'score': 0.9975366592407227},
#  {'label': 'NEGATIVE', 'score': 0.9785701036453247},
#  {'label': 'NEGATIVE', 'score': 0.9641415476799011},
#  {'label': 'NEGATIVE', 'score': 0.9964175224304199},
#  {'label': 'NEGATIVE', 'score': 0.9995802044868469},
#  {'label': 'NEGATIVE', 'score': 0.9987832903862},
#  {'label': 'NEGATIVE', 'score': 0.9967340230941772},
#  {'label': 'POSITIVE', 'score': 0.9963346719741821},
#  {'label': 'NEGATIVE', 'score': 0.978244960308075},
#  {'label': 'NEGATIVE', 'score': 0.9782387018203735},
#  {'label': 'NEGATIVE', 'score': 0.9962437152862549},
#  {'label': 'NEGATIVE', 'score': 0.9985085129737854},
#  {'label': 'POSITIVE', 'score': 0.9997974038124084},
#  {'label': 'NEGATIVE', 'score': 0.9548012614250183},
#  {'label': 'NEGATIVE', 'score': 0.680099606513977},
#  {'label': 'NEGATIVE', 'score': 0.9512196183204651},
#  {'label': 'NEGATIVE', 'score': 0.9956133365631104},
#  {'label': 'POSITIVE', 'score': 0.999327540397644},
#  {'label': 'NEGATIVE', 'score': 0.9898062348365784},
#  {'label': 'NEGATIVE', 'score': 0.994387149810791},
#  {'label': 'NEGATIVE', 'score': 0.7289087176322937},
#  {'label': 'POSITIVE', 'score': 0.9449846744537354},
#  {'label': 'NEGATIVE', 'score': 0.9936564564704895},
#  {'label': 'NEGATIVE', 'score': 0.9992533326148987},
#  {'label': 'NEGATIVE', 'score': 0.9947056174278259},
#  {'label': 'NEGATIVE', 'score': 0.9934380650520325},
#  {'label': 'NEGATIVE', 'score': 0.9953924417495728},
#  {'label': 'POSITIVE', 'score': 0.9982388019561768},
#  {'label': 'NEGATIVE', 'score': 0.9987648725509644},
#  {'label': 'NEGATIVE', 'score': 0.9541437029838562},
#  {'label': 'NEGATIVE', 'score': 0.999180018901825},
#  {'label': 'POSITIVE', 'score': 0.9765006303787231},
#  {'label': 'POSITIVE', 'score': 0.9992327690124512},
#  {'label': 'POSITIVE', 'score': 0.9998550415039062},
#  {'label': 'NEGATIVE', 'score': 0.9975026249885559},
#  {'label': 'NEGATIVE', 'score': 0.9983023405075073},
#  {'label': 'NEGATIVE', 'score': 0.9876882433891296},
#  {'label': 'NEGATIVE', 'score': 0.997796893119812},
#  {'label': 'NEGATIVE', 'score': 0.763094425201416},
#  {'label': 'NEGATIVE', 'score': 0.977268636226654},
#  {'label': 'NEGATIVE', 'score': 0.9926186203956604},
#  {'label': 'NEGATIVE', 'score': 0.9991231560707092},
#  {'label': 'NEGATIVE', 'score': 0.9451863169670105},
#  {'label': 'NEGATIVE', 'score': 0.9993665814399719},
#  {'label': 'NEGATIVE', 'score': 0.9988331198692322},
#  {'label': 'NEGATIVE', 'score': 0.9995965361595154},
#  {'label': 'NEGATIVE', 'score': 0.9983905553817749},
#  {'label': 'NEGATIVE', 'score': 0.9960052371025085},
#  {'label': 'NEGATIVE', 'score': 0.9997357726097107},
#  {'label': 'POSITIVE', 'score': 0.9989911913871765},
#  {'label': 'POSITIVE', 'score': 0.9990088939666748},
#  {'label': 'POSITIVE', 'score': 0.9998862743377686},
#  {'label': 'POSITIVE', 'score': 0.9995274543762207},
#  {'label': 'NEGATIVE', 'score': 0.9980098605155945},
#  {'label': 'NEGATIVE', 'score': 0.9962854385375977},
#  {'label': 'POSITIVE', 'score': 0.9994946718215942},
#  {'label': 'POSITIVE', 'score': 0.9682023525238037},
#  {'label': 'POSITIVE', 'score': 0.9996987581253052},
#  {'label': 'POSITIVE', 'score': 0.9989025592803955},
#  {'label': 'NEGATIVE', 'score': 0.999659538269043},
#  {'label': 'NEGATIVE', 'score': 0.9455071091651917},
#  {'label': 'NEGATIVE', 'score': 0.9988697171211243},
#  {'label': 'NEGATIVE', 'score': 0.9954996705055237},
#  {'label': 'POSITIVE', 'score': 0.9500876665115356},
#  {'label': 'POSITIVE', 'score': 0.9997716546058655},
#  {'label': 'NEGATIVE', 'score': 0.9987654685974121},
#  {'label': 'POSITIVE', 'score': 0.8291963338851929},
#  {'label': 'NEGATIVE', 'score': 0.9878760576248169},
#  {'label': 'POSITIVE', 'score': 0.9997513890266418},
#  {'label': 'NEGATIVE', 'score': 0.9903876185417175},
#  {'label': 'NEGATIVE', 'score': 0.9833803176879883},
#  {'label': 'NEGATIVE', 'score': 0.9997979998588562},
#  {'label': 'POSITIVE', 'score': 0.9914746284484863},
#  {'label': 'POSITIVE', 'score': 0.9996054768562317},
#  {'label': 'POSITIVE', 'score': 0.9689320921897888},
#  {'label': 'POSITIVE', 'score': 0.9960028529167175},
#  {'label': 'POSITIVE', 'score': 0.9984020590782166},
#  {'label': 'NEGATIVE', 'score': 0.9646088480949402},
#  {'label': 'NEGATIVE', 'score': 0.9992351531982422},
#  {'label': 'NEGATIVE', 'score': 0.9943029880523682},
#  {'label': 'NEGATIVE', 'score': 0.9513596296310425},
#  {'label': 'NEGATIVE', 'score': 0.9927027225494385},
#  {'label': 'POSITIVE', 'score': 0.5125895738601685},
#  {'label': 'NEGATIVE', 'score': 0.9988371729850769},
#  {'label': 'NEGATIVE', 'score': 0.9997435212135315},
#  {'label': 'NEGATIVE', 'score': 0.9786626696586609},
#  {'label': 'POSITIVE', 'score': 0.8410556316375732},
#  {'label': 'NEGATIVE', 'score': 0.9697759747505188},
#  {'label': 'NEGATIVE', 'score': 0.9814754724502563},
#  {'label': 'POSITIVE', 'score': 0.9614049196243286},
#  {'label': 'NEGATIVE', 'score': 0.9837212562561035},
#  {'label': 'NEGATIVE', 'score': 0.9674977660179138},
#  {'label': 'NEGATIVE', 'score': 0.9338131546974182},
#  {'label': 'NEGATIVE', 'score': 0.998128354549408},
#  {'label': 'POSITIVE', 'score': 0.9483669400215149},
#  {'label': 'NEGATIVE', 'score': 0.9974120259284973},
#  {'label': 'NEGATIVE', 'score': 0.9802477955818176},
#  {'label': 'POSITIVE', 'score': 0.9867709875106812},
#  {'label': 'NEGATIVE', 'score': 0.7884719967842102},
#  {'label': 'POSITIVE', 'score': 0.9872920513153076},
#  {'label': 'POSITIVE', 'score': 0.9992431402206421},
#  {'label': 'NEGATIVE', 'score': 0.9997106194496155},
#  {'label': 'NEGATIVE', 'score': 0.9997146725654602},
#  {'label': 'POSITIVE', 'score': 0.9794546365737915},
#  {'label': 'NEGATIVE', 'score': 0.9997219443321228},
#  {'label': 'NEGATIVE', 'score': 0.9997792840003967},
#  {'label': 'POSITIVE', 'score': 0.9994527697563171},
#  {'label': 'NEGATIVE', 'score': 0.9995648264884949},
#  {'label': 'NEGATIVE', 'score': 0.7143147587776184},
#  {'label': 'POSITIVE', 'score': 0.9998822212219238},
#  {'label': 'POSITIVE', 'score': 0.9799889326095581},
#  {'label': 'POSITIVE', 'score': 0.999413251876831},
#  {'label': 'NEGATIVE', 'score': 0.9939002990722656},
#  {'label': 'NEGATIVE', 'score': 0.9922205805778503},
#  {'label': 'NEGATIVE', 'score': 0.948390007019043},
#  {'label': 'NEGATIVE', 'score': 0.995315432548523},
#  {'label': 'POSITIVE', 'score': 0.6850008368492126},
#  {'label': 'POSITIVE', 'score': 0.8978191614151001},
#  {'label': 'POSITIVE', 'score': 0.9026621580123901},
#  {'label': 'POSITIVE', 'score': 0.574506938457489},
#  {'label': 'NEGATIVE', 'score': 0.9983406066894531},
#  {'label': 'POSITIVE', 'score': 0.9931414723396301},
#  {'label': 'NEGATIVE', 'score': 0.9942395687103271},
#  {'label': 'POSITIVE', 'score': 0.8889707326889038},
#  {'label': 'NEGATIVE', 'score': 0.783520519733429},
#  {'label': 'NEGATIVE', 'score': 0.9990333318710327},
#  {'label': 'NEGATIVE', 'score': 0.9983052015304565},
#  {'label': 'POSITIVE', 'score': 0.9964455962181091},
#  {'label': 'NEGATIVE', 'score': 0.9933711290359497},
#  {'label': 'NEGATIVE', 'score': 0.9991133809089661},
#  {'label': 'POSITIVE', 'score': 0.9556355476379395},
#  {'label': 'NEGATIVE', 'score': 0.9862428903579712},
#  {'label': 'NEGATIVE', 'score': 0.9978892207145691},
#  {'label': 'NEGATIVE', 'score': 0.9979846477508545},
#  {'label': 'POSITIVE', 'score': 0.979150116443634},
#  {'label': 'NEGATIVE', 'score': 0.5609716773033142},
#  {'label': 'NEGATIVE', 'score': 0.9978728294372559},
#  {'label': 'NEGATIVE', 'score': 0.9997627139091492},
#  {'label': 'POSITIVE', 'score': 0.9338551759719849},
#  {'label': 'NEGATIVE', 'score': 0.9891890287399292},
#  {'label': 'NEGATIVE', 'score': 0.9941349625587463},
#  {'label': 'NEGATIVE', 'score': 0.994549572467804},
#  {'label': 'NEGATIVE', 'score': 0.9976309537887573},
#  {'label': 'NEGATIVE', 'score': 0.9792770743370056},
#  {'label': 'NEGATIVE', 'score': 0.999077320098877},
#  {'label': 'NEGATIVE', 'score': 0.999330997467041},
#  {'label': 'NEGATIVE', 'score': 0.9997223019599915},
#  {'label': 'NEGATIVE', 'score': 0.9938883185386658},
#  {'label': 'NEGATIVE', 'score': 0.9989342093467712},
#  {'label': 'NEGATIVE', 'score': 0.9597233533859253},
#  {'label': 'NEGATIVE', 'score': 0.9913836717605591},
#  {'label': 'NEGATIVE', 'score': 0.6624287962913513},
#  {'label': 'NEGATIVE', 'score': 0.9913653135299683},
#  {'label': 'NEGATIVE', 'score': 0.9923604130744934},
#  {'label': 'NEGATIVE', 'score': 0.9487881660461426},
#  {'label': 'NEGATIVE', 'score': 0.9976473450660706},
#  {'label': 'NEGATIVE', 'score': 0.6792095899581909},
#  {'label': 'NEGATIVE', 'score': 0.9965533018112183},
#  {'label': 'NEGATIVE', 'score': 0.8454969525337219},
#  {'label': 'NEGATIVE', 'score': 0.9997332692146301},
#  {'label': 'NEGATIVE', 'score': 0.9972795844078064},
#  {'label': 'NEGATIVE', 'score': 0.9946817755699158},
#  {'label': 'NEGATIVE', 'score': 0.9719931483268738},
#  {'label': 'POSITIVE', 'score': 0.9996565580368042},
#  {'label': 'NEGATIVE', 'score': 0.9814546704292297},
#  {'label': 'NEGATIVE', 'score': 0.9973148703575134},
#  {'label': 'NEGATIVE', 'score': 0.9540183544158936},
#  {'label': 'POSITIVE', 'score': 0.9864338636398315},
#  {'label': 'NEGATIVE', 'score': 0.9730132222175598},
#  {'label': 'NEGATIVE', 'score': 0.6787955164909363},
#  {'label': 'NEGATIVE', 'score': 0.9994403719902039},
#  {'label': 'NEGATIVE', 'score': 0.8388643860816956},
#  {'label': 'NEGATIVE', 'score': 0.9992807507514954},
#  {'label': 'NEGATIVE', 'score': 0.7690862417221069},
#  {'label': 'NEGATIVE', 'score': 0.9993591904640198},
#  {'label': 'POSITIVE', 'score': 0.9989379048347473},
#  {'label': 'NEGATIVE', 'score': 0.9856598377227783},
#  {'label': 'POSITIVE', 'score': 0.9998798370361328},
#  {'label': 'NEGATIVE', 'score': 0.997147262096405},
#  {'label': 'NEGATIVE', 'score': 0.9985938668251038},
#  {'label': 'NEGATIVE', 'score': 0.9993594288825989},
#  {'label': 'POSITIVE', 'score': 0.9936343431472778},
#  {'label': 'POSITIVE', 'score': 0.998785674571991},
#  {'label': 'NEGATIVE', 'score': 0.99561607837677},
#  {'label': 'POSITIVE', 'score': 0.9872906804084778},
#  {'label': 'POSITIVE', 'score': 0.8826946020126343},
#  {'label': 'NEGATIVE', 'score': 0.9928619265556335},
#  {'label': 'POSITIVE', 'score': 0.9956889748573303},
#  {'label': 'NEGATIVE', 'score': 0.9904264807701111},
#  {'label': 'NEGATIVE', 'score': 0.9752354621887207},
#  {'label': 'NEGATIVE', 'score': 0.933016300201416},
#  {'label': 'POSITIVE', 'score': 0.9994702935218811},
#  {'label': 'POSITIVE', 'score': 0.9777883887290955},
#  {'label': 'NEGATIVE', 'score': 0.9842844009399414},
#  {'label': 'POSITIVE', 'score': 0.9991281628608704},
#  {'label': 'NEGATIVE', 'score': 0.9936175346374512},
#  {'label': 'POSITIVE', 'score': 0.9819886088371277},
#  {'label': 'POSITIVE', 'score': 0.9985425472259521},
#  {'label': 'POSITIVE', 'score': 0.9995787739753723},
#  {'label': 'POSITIVE', 'score': 0.9619609117507935},
#  {'label': 'POSITIVE', 'score': 0.9854621887207031},
#  {'label': 'NEGATIVE', 'score': 0.9739416241645813},
#  {'label': 'NEGATIVE', 'score': 0.9755919575691223},
#  {'label': 'POSITIVE', 'score': 0.9978158473968506},
#  {'label': 'POSITIVE', 'score': 0.9894513487815857},
#  {'label': 'POSITIVE', 'score': 0.9894340634346008},
#  {'label': 'POSITIVE', 'score': 0.9541352987289429},
#  {'label': 'POSITIVE', 'score': 0.9997714161872864},
#  {'label': 'POSITIVE', 'score': 0.994509756565094},
#  {'label': 'POSITIVE', 'score': 0.9998310804367065},
#  {'label': 'NEGATIVE', 'score': 0.9948816299438477},
#  {'label': 'NEGATIVE', 'score': 0.9965481162071228},
#  {'label': 'NEGATIVE', 'score': 0.9962263107299805},
#  {'label': 'POSITIVE', 'score': 0.9940268993377686},
#  {'label': 'POSITIVE', 'score': 0.976037859916687},
#  {'label': 'NEGATIVE', 'score': 0.9993439316749573},
#  {'label': 'NEGATIVE', 'score': 0.9870081543922424},
#  {'label': 'NEGATIVE', 'score': 0.9996439218521118},
#  {'label': 'NEGATIVE', 'score': 0.999556839466095},
#  {'label': 'NEGATIVE', 'score': 0.9992514252662659},
#  {'label': 'NEGATIVE', 'score': 0.995945155620575},
#  {'label': 'NEGATIVE', 'score': 0.9977219700813293},
#  {'label': 'NEGATIVE', 'score': 0.9945510029792786},
#  {'label': 'NEGATIVE', 'score': 0.9992074370384216},
#  {'label': 'NEGATIVE', 'score': 0.9969690442085266},
#  {'label': 'NEGATIVE', 'score': 0.9798517823219299},
#  {'label': 'NEGATIVE', 'score': 0.9688192009925842},
#  {'label': 'NEGATIVE', 'score': 0.999782145023346},
#  {'label': 'NEGATIVE', 'score': 0.9959049820899963},
#  {'label': 'NEGATIVE', 'score': 0.9459059238433838},
#  {'label': 'NEGATIVE', 'score': 0.9845860600471497},
#  {'label': 'POSITIVE', 'score': 0.9990511536598206},
#  {'label': 'NEGATIVE', 'score': 0.9896072745323181},
#  {'label': 'POSITIVE', 'score': 0.9919949769973755},
#  {'label': 'POSITIVE', 'score': 0.9951553344726562},
#  {'label': 'POSITIVE', 'score': 0.9986658096313477},
#  {'label': 'NEGATIVE', 'score': 0.9995806813240051},
#  {'label': 'NEGATIVE', 'score': 0.9921360015869141},
#  {'label': 'POSITIVE', 'score': 0.9995878338813782},
#  {'label': 'NEGATIVE', 'score': 0.9954550266265869},
#  {'label': 'POSITIVE', 'score': 0.9967370629310608},
#  {'label': 'NEGATIVE', 'score': 0.9985527396202087},
#  {'label': 'NEGATIVE', 'score': 0.9996308088302612},
#  {'label': 'POSITIVE', 'score': 0.9991008043289185},
#  {'label': 'POSITIVE', 'score': 0.9995937943458557},
#  {'label': 'NEGATIVE', 'score': 0.9861204028129578},
#  {'label': 'NEGATIVE', 'score': 0.9992677569389343},
#  {'label': 'NEGATIVE', 'score': 0.9988353848457336},
#  {'label': 'NEGATIVE', 'score': 0.5040080547332764},
#  {'label': 'NEGATIVE', 'score': 0.9613381624221802},
#  {'label': 'POSITIVE', 'score': 0.6583179235458374},
#  {'label': 'POSITIVE', 'score': 0.9499454498291016},
#  {'label': 'POSITIVE', 'score': 0.7417784929275513},
#  {'label': 'POSITIVE', 'score': 0.5586445927619934},
#  {'label': 'POSITIVE', 'score': 0.7318202257156372},
#  {'label': 'POSITIVE', 'score': 0.9998681545257568},
#  {'label': 'POSITIVE', 'score': 0.9998657703399658},
#  {'label': 'POSITIVE', 'score': 0.9995989203453064},
#  {'label': 'NEGATIVE', 'score': 0.992875337600708},
#  {'label': 'NEGATIVE', 'score': 0.9995138645172119},
#  {'label': 'NEGATIVE', 'score': 0.9876870512962341},
#  {'label': 'POSITIVE', 'score': 0.9996466636657715},
#  {'label': 'NEGATIVE', 'score': 0.6954150199890137},
#  {'label': 'POSITIVE', 'score': 0.9991869330406189},
#  {'label': 'NEGATIVE', 'score': 0.9567937850952148},
#  {'label': 'NEGATIVE', 'score': 0.9466018676757812},
#  {'label': 'POSITIVE', 'score': 0.9785982966423035},
#  {'label': 'POSITIVE', 'score': 0.9475081562995911},
#  {'label': 'POSITIVE', 'score': 0.9670273065567017},
#  {'label': 'NEGATIVE', 'score': 0.9396486282348633},
#  {'label': 'NEGATIVE', 'score': 0.9991372227668762},
#  {'label': 'POSITIVE', 'score': 0.9997194409370422},
#  {'label': 'NEGATIVE', 'score': 0.9941697120666504},
#  {'label': 'NEGATIVE', 'score': 0.9993664622306824},
#  {'label': 'POSITIVE', 'score': 0.9990116357803345},
#  {'label': 'NEGATIVE', 'score': 0.999580442905426},
#  {'label': 'POSITIVE', 'score': 0.9998457431793213},
#  {'label': 'NEGATIVE', 'score': 0.9996954202651978},
#  {'label': 'NEGATIVE', 'score': 0.9998049139976501},
#  {'label': 'POSITIVE', 'score': 0.9960454106330872},
#  {'label': 'NEGATIVE', 'score': 0.9993574023246765},
#  {'label': 'POSITIVE', 'score': 0.9956988096237183},
#  {'label': 'POSITIVE', 'score': 0.9997746348381042},
#  {'label': 'POSITIVE', 'score': 0.9972999691963196},
#  {'label': 'NEGATIVE', 'score': 0.9858884215354919},
#  {'label': 'POSITIVE', 'score': 0.6471487879753113},
#  {'label': 'NEGATIVE', 'score': 0.9941096305847168},
#  {'label': 'NEGATIVE', 'score': 0.9991819262504578},
#  {'label': 'NEGATIVE', 'score': 0.9996765851974487},
#  {'label': 'NEGATIVE', 'score': 0.9990049004554749},
#  {'label': 'NEGATIVE', 'score': 0.9970211386680603},
#  {'label': 'NEGATIVE', 'score': 0.9942585229873657},
#  {'label': 'NEGATIVE', 'score': 0.9984619617462158},
#  {'label': 'NEGATIVE', 'score': 0.9996142387390137},
#  {'label': 'NEGATIVE', 'score': 0.9871141910552979},
#  {'label': 'POSITIVE', 'score': 0.5124141573905945},
#  {'label': 'NEGATIVE', 'score': 0.9702432751655579},
#  {'label': 'POSITIVE', 'score': 0.9994506239891052},
#  {'label': 'NEGATIVE', 'score': 0.8739112615585327},
#  {'label': 'POSITIVE', 'score': 0.9226060509681702},
#  {'label': 'POSITIVE', 'score': 0.9945189356803894},
#  {'label': 'POSITIVE', 'score': 0.9998165965080261},
#  {'label': 'NEGATIVE', 'score': 0.9741386771202087},
#  {'label': 'POSITIVE', 'score': 0.9803223013877869},
#  {'label': 'NEGATIVE', 'score': 0.9963032007217407},
#  {'label': 'POSITIVE', 'score': 0.6545474529266357},
#  {'label': 'POSITIVE', 'score': 0.9871019721031189},
#  {'label': 'NEGATIVE', 'score': 0.9632229208946228},
#  {'label': 'POSITIVE', 'score': 0.999725878238678},
#  {'label': 'POSITIVE', 'score': 0.9993508458137512},
#  {'label': 'NEGATIVE', 'score': 0.9792063236236572},
#  {'label': 'NEGATIVE', 'score': 0.9312151074409485},
#  {'label': 'POSITIVE', 'score': 0.9780188798904419},
#  {'label': 'NEGATIVE', 'score': 0.9892288446426392},
#  {'label': 'NEGATIVE', 'score': 0.9978339076042175},
#  {'label': 'NEGATIVE', 'score': 0.9948456287384033},
#  {'label': 'POSITIVE', 'score': 0.9988133907318115},
#  {'label': 'POSITIVE', 'score': 0.9996597766876221},
#  {'label': 'POSITIVE', 'score': 0.9995991587638855},
#  {'label': 'POSITIVE', 'score': 0.6851556897163391},
#  {'label': 'POSITIVE', 'score': 0.9990774393081665},
#  {'label': 'NEGATIVE', 'score': 0.9642834067344666},
#  {'label': 'POSITIVE', 'score': 0.9939899444580078},
#  {'label': 'NEGATIVE', 'score': 0.9982522130012512},
#  {'label': 'NEGATIVE', 'score': 0.9950478076934814},
#  {'label': 'POSITIVE', 'score': 0.9977824091911316},
#  {'label': 'POSITIVE', 'score': 0.9245597124099731},
#  {'label': 'NEGATIVE', 'score': 0.7218338847160339},
#  {'label': 'POSITIVE', 'score': 0.9965033531188965},
#  {'label': 'POSITIVE', 'score': 0.9994006156921387},
#  {'label': 'POSITIVE', 'score': 0.9998027682304382},
#  {'label': 'NEGATIVE', 'score': 0.9857903718948364},
#  {'label': 'POSITIVE', 'score': 0.9829551577568054},
#  {'label': 'POSITIVE', 'score': 0.9984123706817627},
#  {'label': 'POSITIVE', 'score': 0.9998131394386292},
#  {'label': 'POSITIVE', 'score': 0.9998158812522888},
#  {'label': 'NEGATIVE', 'score': 0.570195734500885},
#  {'label': 'POSITIVE', 'score': 0.9996675252914429},
#  {'label': 'NEGATIVE', 'score': 0.5026606321334839},
#  {'label': 'NEGATIVE', 'score': 0.9905076026916504},
#  {'label': 'NEGATIVE', 'score': 0.9990586638450623},
#  {'label': 'POSITIVE', 'score': 0.9649839997291565},
#  {'label': 'NEGATIVE', 'score': 0.9705961346626282},
#  {'label': 'POSITIVE', 'score': 0.9990205764770508},
#  {'label': 'NEGATIVE', 'score': 0.9983437061309814},
#  {'label': 'POSITIVE', 'score': 0.8736066818237305},
#  {'label': 'NEGATIVE', 'score': 0.9860895872116089},
#  {'label': 'NEGATIVE', 'score': 0.9832332730293274},
#  {'label': 'NEGATIVE', 'score': 0.9942852854728699},
#  {'label': 'NEGATIVE', 'score': 0.9769221544265747},
#  {'label': 'NEGATIVE', 'score': 0.9533923864364624},
#  {'label': 'POSITIVE', 'score': 0.9905776977539062},
#  {'label': 'NEGATIVE', 'score': 0.9811961650848389},
#  {'label': 'NEGATIVE', 'score': 0.9970613121986389},
#  {'label': 'NEGATIVE', 'score': 0.9992828965187073},
#  {'label': 'NEGATIVE', 'score': 0.9916151762008667},
#  {'label': 'NEGATIVE', 'score': 0.9976602792739868},
#  {'label': 'NEGATIVE', 'score': 0.9750590920448303},
#  {'label': 'NEGATIVE', 'score': 0.9812187552452087},
#  {'label': 'NEGATIVE', 'score': 0.8817514777183533},
#  {'label': 'NEGATIVE', 'score': 0.7047779560089111},
#  {'label': 'NEGATIVE', 'score': 0.9961137771606445},
#  {'label': 'POSITIVE', 'score': 0.993353009223938},
#  {'label': 'NEGATIVE', 'score': 0.9865694046020508},
#  {'label': 'NEGATIVE', 'score': 0.9955861568450928},
#  {'label': 'POSITIVE', 'score': 0.8276369571685791},
#  {'label': 'NEGATIVE', 'score': 0.9984948635101318},
#  {'label': 'NEGATIVE', 'score': 0.9938754439353943},
#  {'label': 'NEGATIVE', 'score': 0.9848936200141907},
#  {'label': 'POSITIVE', 'score': 0.9992260932922363},
#  {'label': 'NEGATIVE', 'score': 0.9857684969902039},
#  {'label': 'NEGATIVE', 'score': 0.991798996925354},
#  {'label': 'POSITIVE', 'score': 0.9979973435401917},
#  {'label': 'POSITIVE', 'score': 0.9237277507781982},
#  {'label': 'POSITIVE', 'score': 0.671237051486969},
#  {'label': 'NEGATIVE', 'score': 0.7202892899513245},
#  {'label': 'POSITIVE', 'score': 0.9998759031295776},
#  {'label': 'NEGATIVE', 'score': 0.9297407269477844},
#  {'label': 'NEGATIVE', 'score': 0.996698260307312},
#  {'label': 'NEGATIVE', 'score': 0.7202252745628357},
#  {'label': 'NEGATIVE', 'score': 0.9531478881835938},
#  {'label': 'NEGATIVE', 'score': 0.9993176460266113},
#  {'label': 'NEGATIVE', 'score': 0.9548798203468323},
#  {'label': 'NEGATIVE', 'score': 0.9968344569206238},
#  {'label': 'POSITIVE', 'score': 0.9949251413345337},
#  {'label': 'POSITIVE', 'score': 0.9956093430519104},
#  {'label': 'NEGATIVE', 'score': 0.983249306678772},
#  {'label': 'POSITIVE', 'score': 0.5682402849197388},
#  {'label': 'POSITIVE', 'score': 0.9991732239723206},
#  {'label': 'POSITIVE', 'score': 0.9996709823608398},
#  {'label': 'POSITIVE', 'score': 0.9993540644645691},
#  {'label': 'POSITIVE', 'score': 0.9974808096885681},
#  {'label': 'POSITIVE', 'score': 0.9994922876358032},
#  {'label': 'POSITIVE', 'score': 0.894233226776123},
#  {'label': 'POSITIVE', 'score': 0.9920997023582458},
#  {'label': 'NEGATIVE', 'score': 0.8678041696548462},
#  {'label': 'POSITIVE', 'score': 0.8952476382255554},
#  {'label': 'POSITIVE', 'score': 0.9953043460845947},
#  {'label': 'POSITIVE', 'score': 0.9991924166679382},
#  {'label': 'POSITIVE', 'score': 0.975996196269989},
#  {'label': 'POSITIVE', 'score': 0.9989863038063049},
#  {'label': 'NEGATIVE', 'score': 0.9231127500534058},
#  {'label': 'POSITIVE', 'score': 0.9872905611991882},
#  {'label': 'POSITIVE', 'score': 0.9931657910346985},
#  {'label': 'POSITIVE', 'score': 0.9767415523529053},
#  {'label': 'POSITIVE', 'score': 0.9960053563117981},
#  {'label': 'POSITIVE', 'score': 0.998124897480011},
#  {'label': 'POSITIVE', 'score': 0.9993141889572144},
#  {'label': 'NEGATIVE', 'score': 0.9915251135826111},
#  {'label': 'NEGATIVE', 'score': 0.9573328495025635},
#  {'label': 'NEGATIVE', 'score': 0.9992188215255737},
#  {'label': 'POSITIVE', 'score': 0.9998018145561218},
#  {'label': 'NEGATIVE', 'score': 0.9989042282104492},
#  {'label': 'NEGATIVE', 'score': 0.9889774918556213},
#  {'label': 'POSITIVE', 'score': 0.9334194660186768},
#  {'label': 'NEGATIVE', 'score': 0.9057121276855469},
#  {'label': 'NEGATIVE', 'score': 0.9853295683860779},
#  {'label': 'POSITIVE', 'score': 0.99892657995224},
#  {'label': 'NEGATIVE', 'score': 0.9818203449249268},
#  {'label': 'POSITIVE', 'score': 0.9996546506881714},
#  {'label': 'NEGATIVE', 'score': 0.9978026747703552},
#  {'label': 'POSITIVE', 'score': 0.9997863173484802},
#  {'label': 'NEGATIVE', 'score': 0.9934349060058594},
#  {'label': 'NEGATIVE', 'score': 0.9997153878211975},
#  {'label': 'NEGATIVE', 'score': 0.9996786117553711},
#  {'label': 'POSITIVE', 'score': 0.9950626492500305},
#  {'label': 'NEGATIVE', 'score': 0.9997993111610413},
#  {'label': 'NEGATIVE', 'score': 0.999735414981842},
#  {'label': 'NEGATIVE', 'score': 0.9976805448532104},
#  {'label': 'NEGATIVE', 'score': 0.6285693049430847},
#  {'label': 'POSITIVE', 'score': 0.9985004663467407},
#  {'label': 'POSITIVE', 'score': 0.9974182844161987},
#  {'label': 'POSITIVE', 'score': 0.9609246850013733},
#  {'label': 'POSITIVE', 'score': 0.9998059868812561},
#  {'label': 'POSITIVE', 'score': 0.9998689889907837},
#  {'label': 'POSITIVE', 'score': 0.9996029734611511},
#  {'label': 'POSITIVE', 'score': 0.9987724423408508},
#  {'label': 'POSITIVE', 'score': 0.9966239929199219},
#  {'label': 'POSITIVE', 'score': 0.9946684241294861},
#  {'label': 'POSITIVE', 'score': 0.9927002787590027},
#  {'label': 'NEGATIVE', 'score': 0.9302958846092224},
#  {'label': 'POSITIVE', 'score': 0.9994865655899048},
#  {'label': 'NEGATIVE', 'score': 0.9908706545829773},
#  {'label': 'POSITIVE', 'score': 0.9993163347244263},
#  {'label': 'NEGATIVE', 'score': 0.9857257604598999},
#  {'label': 'POSITIVE', 'score': 0.9983077049255371},
#  {'label': 'POSITIVE', 'score': 0.9983521699905396},
#  {'label': 'POSITIVE', 'score': 0.9997887015342712},
#  {'label': 'POSITIVE', 'score': 0.9940534234046936},
#  {'label': 'POSITIVE', 'score': 0.9997410178184509},
#  {'label': 'NEGATIVE', 'score': 0.9991984963417053},
#  {'label': 'POSITIVE', 'score': 0.9984279870986938},
#  {'label': 'POSITIVE', 'score': 0.9985747337341309},
#  {'label': 'POSITIVE', 'score': 0.9997802376747131},
#  {'label': 'POSITIVE', 'score': 0.9994869232177734},
#  {'label': 'POSITIVE', 'score': 0.9933469295501709},
#  {'label': 'POSITIVE', 'score': 0.998968243598938},
#  {'label': 'POSITIVE', 'score': 0.9782375693321228},
#  {'label': 'POSITIVE', 'score': 0.9989141225814819},
#  {'label': 'POSITIVE', 'score': 0.9994914531707764},
#  {'label': 'NEGATIVE', 'score': 0.9963359832763672},
#  {'label': 'NEGATIVE', 'score': 0.9980801343917847},
#  {'label': 'NEGATIVE', 'score': 0.5640981793403625},
#  {'label': 'NEGATIVE', 'score': 0.5702006220817566},
#  {'label': 'POSITIVE', 'score': 0.9697911143302917},
#  {'label': 'NEGATIVE', 'score': 0.9826952219009399},
#  {'label': 'NEGATIVE', 'score': 0.6560476422309875},
#  {'label': 'NEGATIVE', 'score': 0.9622374176979065},
#  {'label': 'NEGATIVE', 'score': 0.9878352284431458},
#  {'label': 'POSITIVE', 'score': 0.9973438382148743},
#  {'label': 'POSITIVE', 'score': 0.9984976053237915},
#  {'label': 'POSITIVE', 'score': 0.979563295841217},
#  {'label': 'NEGATIVE', 'score': 0.979889452457428},
#  {'label': 'NEGATIVE', 'score': 0.9777432680130005},
#  {'label': 'POSITIVE', 'score': 0.9970097541809082},
#  {'label': 'POSITIVE', 'score': 0.9997487664222717},
#  {'label': 'POSITIVE', 'score': 0.9969674944877625},
#  {'label': 'POSITIVE', 'score': 0.9989252686500549},
#  {'label': 'NEGATIVE', 'score': 0.7988516688346863},
#  {'label': 'NEGATIVE', 'score': 0.9850833415985107},
#  {'label': 'NEGATIVE', 'score': 0.9997721314430237},
#  {'label': 'NEGATIVE', 'score': 0.980263888835907},
#  {'label': 'NEGATIVE', 'score': 0.9106652736663818},
#  {'label': 'POSITIVE', 'score': 0.9994416832923889},
#  {'label': 'NEGATIVE', 'score': 0.9986472725868225},
#  {'label': 'NEGATIVE', 'score': 0.9977471232414246},
#  {'label': 'POSITIVE', 'score': 0.9993458390235901},
#  {'label': 'NEGATIVE', 'score': 0.9509173631668091},
#  {'label': 'POSITIVE', 'score': 0.9997157454490662},
#  {'label': 'NEGATIVE', 'score': 0.9993212223052979},
#  {'label': 'NEGATIVE', 'score': 0.9993564486503601},
#  {'label': 'POSITIVE', 'score': 0.9997227787971497},
#  {'label': 'POSITIVE', 'score': 0.9824078679084778},
#  {'label': 'POSITIVE', 'score': 0.9998162388801575},
#  {'label': 'POSITIVE', 'score': 0.9991401433944702},
#  {'label': 'POSITIVE', 'score': 0.8567681908607483},
#  {'label': 'NEGATIVE', 'score': 0.9984645843505859},
#  {'label': 'NEGATIVE', 'score': 0.9681905508041382},
#  {'label': 'NEGATIVE', 'score': 0.9997567534446716},
#  {'label': 'NEGATIVE', 'score': 0.9993977546691895},
#  {'label': 'NEGATIVE', 'score': 0.9998055100440979},
#  {'label': 'POSITIVE', 'score': 0.9547985792160034},
#  {'label': 'NEGATIVE', 'score': 0.9992334842681885},
#  {'label': 'NEGATIVE', 'score': 0.9933941960334778},
#  {'label': 'NEGATIVE', 'score': 0.9950201511383057},
#  {'label': 'POSITIVE', 'score': 0.9986099004745483},
#  {'label': 'NEGATIVE', 'score': 0.9872506856918335},
#  {'label': 'NEGATIVE', 'score': 0.9997269511222839},
#  {'label': 'NEGATIVE', 'score': 0.9996994733810425},
#  {'label': 'POSITIVE', 'score': 0.9905710220336914},
#  {'label': 'NEGATIVE', 'score': 0.9511356949806213},
#  {'label': 'POSITIVE', 'score': 0.9998711347579956},
#  {'label': 'NEGATIVE', 'score': 0.850440502166748},
#  {'label': 'POSITIVE', 'score': 0.9997368454933167},
#  {'label': 'POSITIVE', 'score': 0.9983554482460022},
#  {'label': 'POSITIVE', 'score': 0.9998706579208374},
#  {'label': 'POSITIVE', 'score': 0.9994612336158752},
#  {'label': 'POSITIVE', 'score': 0.9978531002998352},
#  {'label': 'NEGATIVE', 'score': 0.9734017848968506},
#  {'label': 'NEGATIVE', 'score': 0.9609723091125488},
#  {'label': 'NEGATIVE', 'score': 0.9976125955581665},
#  {'label': 'POSITIVE', 'score': 0.9985430240631104},
#  {'label': 'NEGATIVE', 'score': 0.7351770997047424},
#  {'label': 'POSITIVE', 'score': 0.991355836391449},
#  {'label': 'POSITIVE', 'score': 0.9986153841018677},
#  {'label': 'NEGATIVE', 'score': 0.9891023635864258},
#  {'label': 'POSITIVE', 'score': 0.9864510297775269},
#  {'label': 'NEGATIVE', 'score': 0.8868147730827332},
#  {'label': 'POSITIVE', 'score': 0.996448278427124},
#  {'label': 'POSITIVE', 'score': 0.9993126392364502},
#  {'label': 'POSITIVE', 'score': 0.9993065595626831},
#  {'label': 'NEGATIVE', 'score': 0.9995397329330444},
#  {'label': 'POSITIVE', 'score': 0.9996015429496765},
#  {'label': 'POSITIVE', 'score': 0.9990975856781006},
#  {'label': 'POSITIVE', 'score': 0.9826479554176331},
#  ...]

# %%
# start here

dicts = {'POSITIVE':1, 'NEGATIVE':0}

sents = np.array([dicts[i['label']] for i in all_sents])

np.sum(sents) / len(sents)
# Out:
# 0.5335128665469778

# %%
df2 = df_tweets.copy()

df2['Date'] = [i[-7:] for i in df_tweets['Date']]
df2
# Out:
#           Date         Time  \
# 0      05/2016  12:00:27 PM
# 1      05/2016   9:53:11 AM
# 2      04/2016   6:30:22 PM
# 3      04/2016   6:23:55 PM
# 4      04/2016   5:47:21 PM
# ...        ...          ...
# 30073  12/2009  10:07:28 AM
# 30074  08/2009   4:40:15 PM
# 30075  08/2009   9:38:08 AM
# 30076  04/2009   9:00:10 PM
# 30077  04/2009   2:54:25 PM
#
#                                                    Tweet               Client  \
# 0      If the press would cover me accurately & honor...   Twitter Web Client
# 1      I am thrilled to nominate Dr. @RealBenCarson a...   Twitter for iPhone
# 2      their country (the U.S. doesn't tax them) or t...  Twitter for Android
# 3      Did China ask us if it was OK to devalue their...  Twitter for Android
# 4      .@FoxNews will be re-running "Objectified: Don...  Twitter for Android
# ...                                                  ...                  ...
# 30073  "My persona will never be that of a wallflower...   Twitter Web Client
# 30074  New Blog Post: Celebrity Apprentice Finale and...   Twitter Web Client
# 30075  Donald Trump reads Top Ten Financial Tips on L...   Twitter Web Client
# 30076  Donald Trump will be appearing on The View tom...   Twitter Web Client
# 30077  Be sure to tune in and watch Donald Trump on L...   Twitter Web Client
#
#          Client Simplified
# 0       Twitter Web Client
# 1       Twitter for iPhone
# 2      Twitter for Android
# 3      Twitter for Android
# 4      Twitter for Android
# ...                    ...
# 30073   Twitter Web Client
# 30074   Twitter Web Client
# 30075   Twitter Web Client
# 30076   Twitter Web Client
# 30077   Twitter Web Client
#
# [30078 rows x 5 columns]

# %%
years =np.unique(df2['Date'])
years
# Out:
# array(['01/2009', '01/2010', '01/2011', '01/2012', '01/2013', '01/2014',
#        '01/2015', '01/2016', '02/2009', '02/2010', '02/2011', '02/2012',
#        '02/2013', '02/2014', '02/2015', '02/2016', '03/2009', '03/2010',
#        '03/2011', '03/2012', '03/2013', '03/2014', '03/2015', '03/2016',
#        '04/2009', '04/2010', '04/2011', '04/2012', '04/2013', '04/2014',
#        '04/2015', '04/2016', '05/2009', '05/2010', '05/2011', '05/2012',
#        '05/2013', '05/2014', '05/2015', '05/2016', '06/2010', '06/2011',
#        '06/2012', '06/2013', '06/2014', '06/2015', '06/2016', '07/2010',
#        '07/2011', '07/2012', '07/2013', '07/2014', '07/2015', '07/2016',
#        '08/2009', '08/2010', '08/2011', '08/2012', '08/2013', '08/2014',
#        '08/2015', '08/2016', '09/2010', '09/2011', '09/2012', '09/2013',
#        '09/2014', '09/2015', '09/2016', '10/2010', '10/2011', '10/2012',
#        '10/2013', '10/2014', '10/2015', '10/2016', '11/2009', '11/2010',
#        '11/2011', '11/2012', '11/2013', '11/2014', '11/2015', '11/2016',
#        '12/2009', '12/2010', '12/2011', '12/2012', '12/2013', '12/2014',
#        '12/2015', '12/2016', '13/2009', '13/2010', '13/2011', '13/2012',
#        '13/2013', '13/2014', '13/2015', '13/2016', '14/2009', '14/2010',
#        '14/2011', '14/2012', '14/2013', '14/2014', '14/2015', '14/2016',
#        '15/2009', '15/2010', '15/2011', '15/2012', '15/2013', '15/2014',
#        '15/2015', '15/2016', '16/2009', '16/2010', '16/2011', '16/2012',
#        '16/2013', '16/2014', '16/2015', '16/2016', '17/2009', '17/2010',
#        '17/2011', '17/2012', '17/2013', '17/2014', '17/2015', '17/2016',
#        '18/2009', '18/2010', '18/2011', '18/2012', '18/2013', '18/2014',
#        '18/2015', '18/2016', '19/2009', '19/2010', '19/2011', '19/2012',
#        '19/2013', '19/2014', '19/2015', '19/2016', '20/2009', '20/2010',
#        '20/2011', '20/2012', '20/2013', '20/2014', '20/2015', '20/2016',
#        '21/2009', '21/2010', '21/2011', '21/2012', '21/2013', '21/2014',
#        '21/2015', '21/2016', '22/2009', '22/2010', '22/2011', '22/2012',
#        '22/2013', '22/2014', '22/2015', '22/2016', '23/2009', '23/2010',
#        '23/2011', '23/2012', '23/2013', '23/2014', '23/2015', '23/2016',
#        '24/2009', '24/2010', '24/2011', '24/2012', '24/2013', '24/2014',
#        '24/2015', '24/2016', '25/2010', '25/2011', '25/2012', '25/2013',
#        '25/2014', '25/2015', '25/2016', '26/2009', '26/2010', '26/2011',
#        '26/2012', '26/2013', '26/2014', '26/2015', '26/2016', '27/2009',
#        '27/2010', '27/2011', '27/2012', '27/2013', '27/2014', '27/2015',
#        '27/2016', '28/2009', '28/2010', '28/2011', '28/2012', '28/2013',
#        '28/2014', '28/2015', '28/2016', '29/2009', '29/2010', '29/2011',
#        '29/2012', '29/2013', '29/2014', '29/2015', '29/2016', '30/2009',
#        '30/2010', '30/2011', '30/2012', '30/2013', '30/2014', '30/2015',
#        '30/2016', '31/2010', '31/2011', '31/2012', '31/2013', '31/2014',
#        '31/2015', '31/2016'], dtype=object)

# %%
years = set(df2['Date'])

# %%
inds = np.where(df2['Date'] == years[0])[0]
inds
# Out:
# array([30022, 30023, 30024, 30025, 30026, 30027, 30028, 30029, 30030,
#        30031, 30032, 30033, 30034, 30035, 30036, 30037, 30038, 30039,
#        30040, 30041, 30042, 30043, 30044, 30045, 30046, 30047, 30048,
#        30049, 30050, 30051, 30052, 30053, 30054, 30055, 30056, 30057,
#        30058, 30059, 30060, 30061, 30062, 30063, 30064, 30065, 30066,
#        30067, 30068, 30069, 30070, 30071, 30072, 30073, 30074, 30075,
#        30076, 30077])

# %%
tmp =sents[inds]
tmp.sum() / len(tmp)
# Out:
# 0.6964285714285714

# %%
props = []
for year in years:
  inds = np.where(df2['Date'] == year)[0] # index for specific year
  tmp = sents[inds] # labels from this year
  prop = tmp.sum() / len(tmp)
  props.append(prop)

props
# Out:
# [0.8333333333333334,
#  0.23529411764705882,
#  0.4426229508196721,
#  0.4166666666666667,
#  0.38095238095238093,
#  0.5992779783393501,
#  0.6666666666666666,
#  0.5028248587570622,
#  0.6448598130841121,
#  0.4166666666666667,
#  0.3488372093023256,
#  0.49743589743589745,
#  0.5714285714285714,
#  0.38461538461538464,
#  0.4166666666666667,
#  1.0,
#  0.6666666666666666,
#  1.0,
#  0.392,
#  0.5720164609053497,
#  0.36507936507936506,
#  0.493006993006993,
#  0.75,
#  0.6050955414012739,
#  0.45535714285714285,
#  0.4678362573099415,
#  0.524822695035461,
#  0.49145299145299143,
#  1.0,
#  0.4675324675324675,
#  0.4375,
#  0.75,
#  0.6666666666666666,
#  0.4305555555555556,
#  0.5990338164251208,
#  0.6666666666666666,
#  0.6845878136200717,
#  0.568,
#  0.18518518518518517,
#  0.39849624060150374,
#  0.5,
#  0.41947565543071164,
#  0.6308724832214765,
#  0.6328502415458938,
#  0.4793814432989691,
#  0.6261261261261262,
#  0.49645390070921985,
#  0.6421052631578947,
#  0.375,
#  0.7142857142857143,
#  0.49489795918367346,
#  0.42857142857142855,
#  0.6596858638743456,
#  0.6442953020134228,
#  0.47058823529411764,
#  0.6666666666666666,
#  0.25925925925925924,
#  0.1,
#  1.0,
#  0.5,
#  0.40540540540540543,
#  0.24,
#  0.4175257731958763,
#  0.47058823529411764,
#  0.4077669902912621,
#  0.7142857142857143,
#  0.25,
#  0.48214285714285715,
#  0.36585365853658536,
#  0.3577981651376147,
#  0.43548387096774194,
#  0.6088328075709779,
#  0.2857142857142857,
#  0.39097744360902253,
#  0.4857142857142857,
#  0.3125,
#  0.0,
#  0.5478927203065134,
#  0.5550660792951542,
#  0.23684210526315788,
#  0.5631399317406144,
#  0.5735294117647058,
#  1.0,
#  0.5525291828793775,
#  0.5045045045045045,
#  0.4215686274509804,
#  0.1,
#  0.4444444444444444,
#  0.38095238095238093,
#  0.4482758620689655,
#  0.5405405405405406,
#  0.4,
#  0.4722222222222222,
#  0.49271137026239065,
#  0.14285714285714285,
#  0.5970873786407767,
#  0.6428571428571429,
#  0.3333333333333333,
#  0.5816993464052288,
#  0.3316062176165803,
#  0.35359116022099446,
#  0.6319018404907976,
#  0.6094420600858369,
#  1.0,
#  0.5386819484240688,
#  0.5506607929515418,
#  0.5,
#  1.0,
#  0.6850393700787402,
#  0.5459459459459459,
#  1.0,
#  1.0,
#  0.529126213592233,
#  0.0,
#  0.5673469387755102,
#  0.6666666666666666,
#  1.0,
#  0.6486486486486487,
#  0.3125,
#  0.4444444444444444,
#  0.4690265486725664,
#  0.5647840531561462,
#  0.5132743362831859,
#  1.0,
#  0.56957928802589,
#  0.0,
#  0.5120274914089347,
#  0.5801886792452831,
#  0.6117216117216118,
#  1.0,
#  1.0,
#  0.5398773006134969,
#  0.5393258426966292,
#  0.5384615384615384,
#  0.5637860082304527,
#  0.4563380281690141,
#  0.423728813559322,
#  0.4329896907216495,
#  1.0,
#  0.5498392282958199,
#  0.5868544600938967,
#  0.5325443786982249,
#  0.3464566929133858,
#  0.3333333333333333,
#  0.3548387096774194,
#  0.4883720930232558,
#  1.0,
#  0.6666666666666666,
#  1.0,
#  0.5978260869565217,
#  0.5948905109489051,
#  0.5539033457249071,
#  0.8333333333333334,
#  0.6129032258064516,
#  1.0,
#  0.3181818181818182,
#  0.5867768595041323,
#  0.629757785467128,
#  0.5,
#  0.5,
#  0.49673202614379086,
#  0.2,
#  0.4805194805194805,
#  0.5847457627118644,
#  1.0,
#  0.5073891625615764,
#  0.6587677725118484,
#  1.0,
#  0.25925925925925924,
#  0.6274509803921569,
#  0.41509433962264153,
#  0.5042016806722689,
#  0.6012269938650306,
#  0.45588235294117646,
#  0.6075949367088608,
#  0.8,
#  0.5816993464052288,
#  0.5285714285714286,
#  0.6802030456852792,
#  0.5272727272727272,
#  0.4154929577464789,
#  0.3987341772151899,
#  0.22727272727272727,
#  0.625,
#  1.0,
#  1.0,
#  0.40476190476190477,
#  0.2222222222222222,
#  0.4380952380952381,
#  0.5338645418326693,
#  0.8333333333333334,
#  0.6666666666666666,
#  1.0,
#  0.36,
#  0.5789473684210527,
#  0.46,
#  0.562874251497006,
#  0.5146198830409356,
#  0.4215686274509804,
#  0.3088235294117647,
#  0.5967741935483871,
#  0.45161290322580644,
#  0.5282258064516129,
#  0.6666666666666666,
#  1.0,
#  0.5486111111111112,
#  0.5,
#  0.5,
#  0.4017094017094017,
#  0.32558139534883723,
#  0.5604838709677419,
#  1.0,
#  0.39080459770114945,
#  0.6666666666666666,
#  0.6150943396226415,
#  0.6357388316151202,
#  1.0,
#  0.375,
#  0.25925925925925924,
#  1.0,
#  0.3904761904761905,
#  0.7276264591439688,
#  0.6987179487179487,
#  0.5521472392638037,
#  0.5964912280701754,
#  0.5510204081632653,
#  0.8,
#  0.5339366515837104,
#  0.5346153846153846,
#  0.5136363636363637,
#  0.5555555555555556,
#  0.5687203791469194,
#  0.45614035087719296,
#  0.75,
#  0.3902439024390244,
#  0.75,
#  0.2857142857142857,
#  0.5743440233236151,
#  0.375,
#  0.6491803278688525,
#  0.0,
#  0.2972972972972973]

# %%
plt.bar(years, props)
plt.show()

# %%
years
# Out:
# {'01/2009',
#  '01/2010',
#  '01/2011',
#  '01/2012',
#  '01/2013',
#  '01/2014',
#  '01/2015',
#  '01/2016',
#  '02/2009',
#  '02/2010',
#  '02/2011',
#  '02/2012',
#  '02/2013',
#  '02/2014',
#  '02/2015',
#  '02/2016',
#  '03/2009',
#  '03/2010',
#  '03/2011',
#  '03/2012',
#  '03/2013',
#  '03/2014',
#  '03/2015',
#  '03/2016',
#  '04/2009',
#  '04/2010',
#  '04/2011',
#  '04/2012',
#  '04/2013',
#  '04/2014',
#  '04/2015',
#  '04/2016',
#  '05/2009',
#  '05/2010',
#  '05/2011',
#  '05/2012',
#  '05/2013',
#  '05/2014',
#  '05/2015',
#  '05/2016',
#  '06/2010',
#  '06/2011',
#  '06/2012',
#  '06/2013',
#  '06/2014',
#  '06/2015',
#  '06/2016',
#  '07/2010',
#  '07/2011',
#  '07/2012',
#  '07/2013',
#  '07/2014',
#  '07/2015',
#  '07/2016',
#  '08/2009',
#  '08/2010',
#  '08/2011',
#  '08/2012',
#  '08/2013',
#  '08/2014',
#  '08/2015',
#  '08/2016',
#  '09/2010',
#  '09/2011',
#  '09/2012',
#  '09/2013',
#  '09/2014',
#  '09/2015',
#  '09/2016',
#  '10/2010',
#  '10/2011',
#  '10/2012',
#  '10/2013',
#  '10/2014',
#  '10/2015',
#  '10/2016',
#  '11/2009',
#  '11/2010',
#  '11/2011',
#  '11/2012',
#  '11/2013',
#  '11/2014',
#  '11/2015',
#  '11/2016',
#  '12/2009',
#  '12/2010',
#  '12/2011',
#  '12/2012',
#  '12/2013',
#  '12/2014',
#  '12/2015',
#  '12/2016',
#  '13/2009',
#  '13/2010',
#  '13/2011',
#  '13/2012',
#  '13/2013',
#  '13/2014',
#  '13/2015',
#  '13/2016',
#  '14/2009',
#  '14/2010',
#  '14/2011',
#  '14/2012',
#  '14/2013',
#  '14/2014',
#  '14/2015',
#  '14/2016',
#  '15/2009',
#  '15/2010',
#  '15/2011',
#  '15/2012',
#  '15/2013',
#  '15/2014',
#  '15/2015',
#  '15/2016',
#  '16/2009',
#  '16/2010',
#  '16/2011',
#  '16/2012',
#  '16/2013',
#  '16/2014',
#  '16/2015',
#  '16/2016',
#  '17/2009',
#  '17/2010',
#  '17/2011',
#  '17/2012',
#  '17/2013',
#  '17/2014',
#  '17/2015',
#  '17/2016',
#  '18/2009',
#  '18/2010',
#  '18/2011',
#  '18/2012',
#  '18/2013',
#  '18/2014',
#  '18/2015',
#  '18/2016',
#  '19/2009',
#  '19/2010',
#  '19/2011',
#  '19/2012',
#  '19/2013',
#  '19/2014',
#  '19/2015',
#  '19/2016',
#  '20/2009',
#  '20/2010',
#  '20/2011',
#  '20/2012',
#  '20/2013',
#  '20/2014',
#  '20/2015',
#  '20/2016',
#  '21/2009',
#  '21/2010',
#  '21/2011',
#  '21/2012',
#  '21/2013',
#  '21/2014',
#  '21/2015',
#  '21/2016',
#  '22/2009',
#  '22/2010',
#  '22/2011',
#  '22/2012',
#  '22/2013',
#  '22/2014',
#  '22/2015',
#  '22/2016',
#  '23/2009',
#  '23/2010',
#  '23/2011',
#  '23/2012',
#  '23/2013',
#  '23/2014',
#  '23/2015',
#  '23/2016',
#  '24/2009',
#  '24/2010',
#  '24/2011',
#  '24/2012',
#  '24/2013',
#  '24/2014',
#  '24/2015',
#  '24/2016',
#  '25/2010',
#  '25/2011',
#  '25/2012',
#  '25/2013',
#  '25/2014',
#  '25/2015',
#  '25/2016',
#  '26/2009',
#  '26/2010',
#  '26/2011',
#  '26/2012',
#  '26/2013',
#  '26/2014',
#  '26/2015',
#  '26/2016',
#  '27/2009',
#  '27/2010',
#  '27/2011',
#  '27/2012',
#  '27/2013',
#  '27/2014',
#  '27/2015',
#  '27/2016',
#  '28/2009',
#  '28/2010',
#  '28/2011',
#  '28/2012',
#  '28/2013',
#  '28/2014',
#  '28/2015',
#  '28/2016',
#  '29/2009',
#  '29/2010',
#  '29/2011',
#  '29/2012',
#  '29/2013',
#  '29/2014',
#  '29/2015',
#  '29/2016',
#  '30/2009',
#  '30/2010',
#  '30/2011',
#  '30/2012',
#  '30/2013',
#  '30/2014',
#  '30/2015',
#  '30/2016',
#  '31/2010',
#  '31/2011',
#  '31/2012',
#  '31/2013',
#  '31/2014',
#  '31/2015',
#  '31/2016'}
